# %% [markdown]
# # Assumptions of a GP

# %% [markdown]
# We compare two scenarios. In one, we fit a GP with "correct" (non-misspecified kernel), in the other we have a mis-specified kernel.

# %%
library(ParamHelpers)
library(mlrMBO)
library(smoof)
library(BBmisc)
library(iml)
library(ggplot2)
library(data.table)
library(rstatix)

theme_set(theme_bw())

library(data.table)

source("../R/pdp_helpers.R")

# %%
simulate_kernel = function(dimension, true_kernel = "matern3_2", wrong_kernel = "matern5_2", n = 50) {

    objective = makeSingleObjectiveFunction(name = paste0("StyblinskiTang", dimension, "D"), fn = function(x) {
        1 / 2 * sum(x^4 - 16 * x^2 + 5 * x)
        }, 
        par.set = makeParamSet(makeNumericVectorParam(id = "x", len = dimension, lower = - 5, upper = 5)), 
        global.opt.params = rep(-2.9035, dimension)
    )

    ps = getParamSet(objective)
    
    # We take an objective function, but approximate it by a Gaussian process, which becomes our new objective function
    ps = getParamSet(objective)
    
    df = generateRandomDesign(n = n, par.set = ps)
    df$y = apply(df, 1, objective)

    tsk = makeRegrTask(id = "", data = df, target = "y")

    lrn_true = makeLearner("regr.km", predict.type = "se", covtype = true_kernel)
    model_true = train(lrn_true, tsk)

    obj_true = makeSingleObjectiveFunction(name = "objective_true", fn = function(x) {
            x = as.data.frame(t(as.matrix(x)))
            colnames(x) = getParamIds(ps, repeated = TRUE, with.nr = TRUE)
            predict(model_true, newdata = x)$data$response[1]
        }, 
        par.set = ps
    )
    
    # Compute for both cases the PD, as well as the log-likelihood
    data = generateRandomDesign(n = 100, par.set = ps)

    # GT pdp
    me = marginal_effect(obj = obj_true, feature = "x1", data = data, model = model_true, all.features = model_true$features, grid.size = 20, method = "pdp")
    me = setDT(me)
    

    
    
    # Now try to approximate obj_true with a GP with the different kernels 
    df_true = df
    df_true$y = apply(df_true[, seq_len(ncol(df) - 1)], 1, objective)

    tsk = makeRegrTask(id = "", data = df_true, target = "y")
    
    ## WRONG KERNEL

    lrn_wrong = makeLearner("regr.km", predict.type = "se", covtype = wrong_kernel, nugget.estim = FALSE)# , nugget.stability = 10^(-8))

    model_wrong = train(lrn_wrong, tsk)

    pdp_wrong_kernel = lapply(c("pdp_var_gp", "pdp_var"), function(method) {
        me_pdp_var = marginal_effect_sd_over_mean(model = model_wrong, "x1", data, 20, method)
        me_pdp_var$type = method
        me_pdp_var$neg_loglik = unlist(lapply(seq_row(me_pdp_var), function(i) {
            - dnorm(me[i, ]$mean, mean = me_pdp_var[i, ]$mean, sd = me_pdp_var[i, ]$sd, log = TRUE) 
        }))
        me_pdp_var$mean.gt = me$mean

        return(me_pdp_var)
    })
    pdp_wrong_kernel = do.call(rbind, pdp_wrong_kernel)
    pdp_wrong_kernel$misspec = TRUE
    
    ## RIGHT KERNEL
    
    lrn_true = makeLearner("regr.km", predict.type = "se", covtype = true_kernel, nugget.estim = FALSE)# , nugget.stability = 10^(-8))

    model_true = train(lrn_true, tsk)
    
    pdp_true_kernel = lapply(c("pdp_var_gp", "pdp_var"), function(method) {
        me_pdp_var = marginal_effect_sd_over_mean(model = model_true, "x1", data, 20, method)
        me_pdp_var$type = method
        me_pdp_var$neg_loglik = unlist(lapply(seq_row(me_pdp_var), function(i) {
            - dnorm(me[i, ]$mean, mean = me_pdp_var[i, ]$mean, sd = me_pdp_var[i, ]$sd, log = TRUE) 
        }))
        me_pdp_var$mean.gt = me$mean
        return(me_pdp_var)
    })
    pdp_true_kernel = do.call(rbind, pdp_true_kernel)
    pdp_true_kernel$misspec = FALSE
    
    
    # Compute the log-likelihood for both cases 

    me_pdp = rbind(pdp_true_kernel, pdp_wrong_kernel)
    me_pdp$dimension = dimension
    
    return(me_pdp)
}

# %%
out_2 = lapply(seq_len(50), function(i) {
        res = simulate_kernel(dimension = 2, true_kernel = "matern3_2", wrong_kernel = "matern5_2", n = 30)
        res$iter = i
    
        res
})
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.66715 18.24466
#   - best initial criterion value(s) :  -137.8647
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       137.86  |proj g|=      0.35702
# At iterate     1  f =       137.74  |proj g|=       0.27993
# At iterate     2  f =       137.48  |proj g|=       0.12964
# At iterate     3  f =       137.34  |proj g|=       0.17272
# At iterate     4  f =       137.06  |proj g|=       0.11919
# At iterate     5  f =       137.01  |proj g|=      0.039281
# At iterate     6  f =       137.01  |proj g|=     0.0044516
# At iterate     7  f =       137.01  |proj g|=    0.00019191
# At iterate     8  f =       137.01  |proj g|=     9.887e-07
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 9.88702e-07
# final function value 137.007
#
# F = 137.007
# final  value 137.007419
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.66715 18.24466
#   - best initial criterion value(s) :  -132.9204
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       132.92  |proj g|=      0.55921
# At iterate     1  f =       132.61  |proj g|=       0.38996
# At iterate     2  f =       132.29  |proj g|=       0.14032
# At iterate     3  f =       132.17  |proj g|=       0.17111
# At iterate     4  f =       132.11  |proj g|=      0.089662
# At iterate     5  f =       132.09  |proj g|=     0.0090596
# At iterate     6  f =       132.09  |proj g|=    0.00050852
# At iterate     7  f =       132.09  |proj g|=    2.9588e-06
# At iterate     8  f =       132.09  |proj g|=    1.9333e-09
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.93333e-09
# final function value 132.085
#
# F = 132.085
# final  value 132.085025
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.66715 18.24466
#   - best initial criterion value(s) :  -137.252
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       137.25  |proj g|=      0.13565
# At iterate     1  f =       137.23  |proj g|=       0.11837
# At iterate     2  f =       137.01  |proj g|=     0.0016122
# At iterate     3  f =       137.01  |proj g|=    0.00071081
# At iterate     4  f =       137.01  |proj g|=    1.3392e-06
# At iterate     5  f =       137.01  |proj g|=    1.1633e-06
#
# iterations 5
# function evaluations 7
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.16325e-06
# final function value 137.007
#
# F = 137.007
# final  value 137.007419
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.85705 18.57986
#   - best initial criterion value(s) :  -138.1984
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        138.2  |proj g|=      0.14565
# At iterate     1  f =       138.16  |proj g|=       0.14268
# At iterate     2  f =       138.11  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 138.11
#
# F = 138.11
# final  value 138.110094
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.85705 18.57986
#   - best initial criterion value(s) :  -136.3552
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       136.36  |proj g|=      0.94838
# At iterate     1  f =       135.59  |proj g|=       0.58515
# At iterate     2  f =       134.88  |proj g|=       0.31705
# At iterate     3  f =       134.22  |proj g|=       0.43321
# At iterate     4  f =       133.51  |proj g|=       0.30989
# At iterate     5  f =       133.34  |proj g|=             0
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 133.341
#
# F = 133.341
# final  value 133.341013
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.85705 18.57986
#   - best initial criterion value(s) :  -139.0057
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       139.01  |proj g|=      0.18921
# At iterate     1  f =       138.95  |proj g|=       0.18504
# At iterate     2  f =       138.11  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 138.11
#
# F = 138.11
# final  value 138.110094
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.7401 19.27409
#   - best initial criterion value(s) :  -142.9053
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       142.91  |proj g|=      0.29765
# At iterate     1  f =       142.82  |proj g|=       0.26449
# At iterate     2  f =       142.24  |proj g|=       0.13524
# At iterate     3  f =       142.17  |proj g|=      0.073271
# At iterate     4  f =       142.15  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 142.152
#
# F = 142.152
# final  value 142.151548
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.7401 19.27409
#   - best initial criterion value(s) :  -142.2712
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       142.27  |proj g|=      0.68027
# At iterate     1  f =       141.83  |proj g|=       0.45865
# At iterate     2  f =       141.43  |proj g|=       0.18269
# At iterate     3  f =       141.39  |proj g|=       0.12468
# At iterate     4  f =       141.35  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 141.355
#
# F = 141.355
# final  value 141.354911
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.7401 19.27409
#   - best initial criterion value(s) :  -143.9107
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       143.91  |proj g|=       0.5051
# At iterate     1  f =       143.68  |proj g|=       0.41344
# At iterate     2  f =       142.86  |proj g|=       0.21828
# At iterate     3  f =       142.32  |proj g|=       0.18226
# At iterate     4  f =       142.15  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 142.152
#
# F = 142.152
# final  value 142.151548
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  15.03043 18.14955
#   - best initial criterion value(s) :  -126.7806
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       126.78  |proj g|=      0.19724
# At iterate     1  f =       126.74  |proj g|=       0.16187
# At iterate     2  f =       126.42  |proj g|=       0.19144
# At iterate     3  f =       126.31  |proj g|=      0.048384
# At iterate     4  f =       126.31  |proj g|=     0.0083928
# At iterate     5  f =       126.31  |proj g|=    0.00029147
# At iterate     6  f =       126.31  |proj g|=    1.8505e-06
# At iterate     7  f =       126.31  |proj g|=     4.132e-10
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 4.13196e-10
# final function value 126.305
#
# F = 126.305
# final  value 126.305490
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  15.03043 18.14955
#   - best initial criterion value(s) :  -125.5009
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        125.5  |proj g|=      0.62964
# At iterate     1  f =       125.31  |proj g|=       0.31616
# At iterate     2  f =       125.04  |proj g|=       0.25358
# At iterate     3  f =       124.35  |proj g|=       0.32008
# At iterate     4  f =       124.19  |proj g|=       0.19501
# At iterate     5  f =       124.14  |proj g|=       0.03012
# At iterate     6  f =       124.14  |proj g|=     0.0018491
# At iterate     7  f =       124.14  |proj g|=    1.9453e-05
# At iterate     8  f =       124.14  |proj g|=    1.2969e-08
#
# iterations 8
# function evaluations 10
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.29686e-08
# final function value 124.138
#
# F = 124.138
# final  value 124.137962
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  15.03043 18.14955
#   - best initial criterion value(s) :  -126.7096
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       126.71  |proj g|=       0.2751
# At iterate     1  f =       126.64  |proj g|=       0.22116
# At iterate     2  f =       126.43  |proj g|=       0.14094
# At iterate     3  f =       126.34  |proj g|=       0.10594
# At iterate     4  f =       126.31  |proj g|=      0.023961
# At iterate     5  f =       126.31  |proj g|=     0.0016903
# At iterate     6  f =       126.31  |proj g|=    3.0067e-05
# At iterate     7  f =       126.31  |proj g|=    3.8748e-08
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.8748e-08
# final function value 126.305
#
# F = 126.305
# final  value 126.305490
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.52211 18.79684
#   - best initial criterion value(s) :  -136.8458
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       136.85  |proj g|=      0.29719
# At iterate     1  f =       136.76  |proj g|=       0.24927
# At iterate     2  f =       136.33  |proj g|=       0.19567
# At iterate     3  f =       135.92  |proj g|=       0.18813
# At iterate     4  f =       135.76  |proj g|=      0.022369
# At iterate     5  f =       135.76  |proj g|=     0.0029447
# At iterate     6  f =       135.76  |proj g|=    5.7436e-05
# At iterate     7  f =       135.76  |proj g|=    1.4316e-07
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.43158e-07
# final function value 135.758
#
# F = 135.758
# final  value 135.758369
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.52211 18.79684
#   - best initial criterion value(s) :  -130.4437
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       130.44  |proj g|=      0.15221
# At iterate     1  f =       130.41  |proj g|=       0.13705
# At iterate     2  f =       130.32  |proj g|=      0.040863
# At iterate     3  f =       130.31  |proj g|=     0.0024041
# At iterate     4  f =       130.31  |proj g|=    3.5096e-05
# At iterate     5  f =       130.31  |proj g|=    3.2056e-08
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.20565e-08
# final function value 130.312
#
# F = 130.312
# final  value 130.312392
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.52211 18.79684
#   - best initial criterion value(s) :  -136.046
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       136.05  |proj g|=        0.203
# At iterate     1  f =       136.01  |proj g|=       0.18169
# At iterate     2  f =       135.79  |proj g|=      0.083751
# At iterate     3  f =       135.77  |proj g|=      0.053713
# At iterate     4  f =       135.76  |proj g|=     0.0032168
# At iterate     5  f =       135.76  |proj g|=    0.00013576
# At iterate     6  f =       135.76  |proj g|=    3.6669e-07
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.6669e-07
# final function value 135.758
#
# F = 135.758
# final  value 135.758369
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.11871 19.06848
#   - best initial criterion value(s) :  -137.7669
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       137.77  |proj g|=      0.20415
# At iterate     1  f =       137.73  |proj g|=       0.18396
# At iterate     2  f =        137.6  |proj g|=      0.038935
# At iterate     3  f =       137.59  |proj g|=      0.027266
# At iterate     4  f =       137.59  |proj g|=    0.00084931
# At iterate     5  f =       137.59  |proj g|=    1.9491e-05
# At iterate     6  f =       137.59  |proj g|=    1.4463e-08
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.44635e-08
# final function value 137.585
#
# F = 137.585
# final  value 137.585403
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.11871 19.06848
#   - best initial criterion value(s) :  -133.2145
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       133.21  |proj g|=      0.71691
# At iterate     1  f =       132.66  |proj g|=       0.44931
# At iterate     2  f =       132.31  |proj g|=       0.12165
# At iterate     3  f =       132.24  |proj g|=       0.14948
# At iterate     4  f =        132.2  |proj g|=      0.078649
# At iterate     5  f =       132.19  |proj g|=     0.0036913
# At iterate     6  f =       132.19  |proj g|=    0.00010051
# At iterate     7  f =       132.19  |proj g|=    1.3492e-07
#
# iterations 7
# function evaluations 9
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.34916e-07
# final function value 132.189
#
# F = 132.189
# final  value 132.189390
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.11871 19.06848
#   - best initial criterion value(s) :  -138.9257
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       138.93  |proj g|=      0.35963
# At iterate     1  f =       138.81  |proj g|=       0.29959
# At iterate     2  f =       138.35  |proj g|=       0.16681
# At iterate     3  f =       137.95  |proj g|=       0.20805
# At iterate     4  f =       137.67  |proj g|=       0.11353
# At iterate     5  f =       137.59  |proj g|=      0.018261
# At iterate     6  f =       137.59  |proj g|=     0.0015315
# At iterate     7  f =       137.59  |proj g|=    2.3804e-05
# At iterate     8  f =       137.59  |proj g|=    3.1823e-08
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.18225e-08
# final function value 137.585
#
# F = 137.585
# final  value 137.585403
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.05042 18.99866
#   - best initial criterion value(s) :  -125.3889
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       125.39  |proj g|=      0.29734
# At iterate     1  f =       125.25  |proj g|=       0.22265
# At iterate     2  f =       125.05  |proj g|=      0.014812
# At iterate     3  f =       125.05  |proj g|=     0.0057723
# At iterate     4  f =       125.05  |proj g|=     0.0084171
# At iterate     5  f =       125.04  |proj g|=      0.013884
# At iterate     6  f =       125.04  |proj g|=      0.011622
# At iterate     7  f =       125.04  |proj g|=    0.00021105
# At iterate     8  f =       125.04  |proj g|=    4.9558e-05
# At iterate     9  f =       125.04  |proj g|=     1.142e-05
#
# iterations 9
# function evaluations 10
# segments explored during Cauchy searches 9
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 1.14201e-05
# final function value 125.042
#
# F = 125.042
# final  value 125.042355
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.05042 18.99866
#   - best initial criterion value(s) :  -117.5126
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       117.51  |proj g|=       0.1414
# At iterate     1  f =       117.49  |proj g|=      0.076539
# At iterate     2  f =       117.48  |proj g|=      0.028272
# At iterate     3  f =       117.48  |proj g|=      0.038757
# At iterate     4  f =       117.46  |proj g|=      0.077716
# At iterate     5  f =       117.43  |proj g|=      0.085697
# At iterate     6  f =       117.41  |proj g|=      0.035318
# At iterate     7  f =       117.41  |proj g|=        0.0116
# At iterate     8  f =       117.41  |proj g|=    0.00015643
# At iterate     9  f =       117.41  |proj g|=     6.748e-07
#
# iterations 9
# function evaluations 10
# segments explored during Cauchy searches 9
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 6.74804e-07
# final function value 117.409
#
# F = 117.409
# final  value 117.408689
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.05042 18.99866
#   - best initial criterion value(s) :  -125.259
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       125.26  |proj g|=      0.15292
# At iterate     1  f =       125.22  |proj g|=       0.13509
# At iterate     2  f =       125.11  |proj g|=      0.027105
# At iterate     3  f =       125.09  |proj g|=      0.032843
# At iterate     4  f =       125.06  |proj g|=      0.047763
# At iterate     5  f =       125.04  |proj g|=      0.019106
# At iterate     6  f =       125.04  |proj g|=      0.003278
# At iterate     7  f =       125.04  |proj g|=    0.00026052
# At iterate     8  f =       125.04  |proj g|=    2.8424e-06
# At iterate     9  f =       125.04  |proj g|=    7.2406e-07
#
# iterations 9
# function evaluations 11
# segments explored during Cauchy searches 9
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 7.24058e-07
# final function value 125.042
#
# F = 125.042
# final  value 125.042355
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.07764 19.02071
#   - best initial criterion value(s) :  -133.4561
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       133.46  |proj g|=      0.23727
# At iterate     1  f =        133.4  |proj g|=        0.2067
# At iterate     2  f =       133.13  |proj g|=       0.11905
# At iterate     3  f =       133.02  |proj g|=     0.0014296
# At iterate     4  f =       133.02  |proj g|=    0.00061024
# At iterate     5  f =       133.02  |proj g|=    8.0193e-07
# At iterate     6  f =       133.02  |proj g|=    8.0194e-07
#
# iterations 6
# function evaluations 23
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 8.01936e-07
# final function value 133.021
#
# F = 133.021
# l(0) > u(0).  No feasible solutionfinal  value 133.021422
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.07764 19.02071
#   - best initial criterion value(s) :  -129.9459
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       129.95  |proj g|=      0.24336
# At iterate     1  f =       129.89  |proj g|=       0.18985
# At iterate     2  f =       129.71  |proj g|=       0.19485
# At iterate     3  f =       129.48  |proj g|=       0.27908
# At iterate     4  f =       129.38  |proj g|=       0.19485
# At iterate     5  f =       129.34  |proj g|=             0
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 129.338
#
# F = 129.338
# final  value 129.337641
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.07764 19.02071
#   - best initial criterion value(s) :  -133.2549
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       133.25  |proj g|=      0.16993
# At iterate     1  f =       133.23  |proj g|=       0.15351
# At iterate     2  f =       133.06  |proj g|=      0.074155
# At iterate     3  f =       133.04  |proj g|=      0.050549
# At iterate     4  f =       133.02  |proj g|=     0.0029778
# At iterate     5  f =       133.02  |proj g|=    0.00012984
# At iterate     6  f =       133.02  |proj g|=    3.5491e-07
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.54906e-07
# final function value 133.021
#
# F = 133.021
# final  value 133.021422
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.78277 19.31373
#   - best initial criterion value(s) :  -140.4356
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       140.44  |proj g|=      0.20157
# At iterate     1  f =       140.39  |proj g|=       0.18301
# At iterate     2  f =       139.84  |proj g|=     0.0085214
# At iterate     3  f =       139.83  |proj g|=     0.0036161
# At iterate     4  f =       139.83  |proj g|=    3.6123e-05
# At iterate     5  f =       139.83  |proj g|=    1.5558e-07
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.55578e-07
# final function value 139.835
#
# F = 139.835
# final  value 139.834752
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.78277 19.31373
#   - best initial criterion value(s) :  -136.11
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       136.11  |proj g|=      0.19405
# At iterate     1  f =       136.06  |proj g|=       0.17223
# At iterate     2  f =       135.64  |proj g|=      0.084283
# At iterate     3  f =       135.63  |proj g|=       0.02199
# At iterate     4  f =       135.63  |proj g|=    0.00064283
# At iterate     5  f =       135.63  |proj g|=    5.2018e-06
# At iterate     6  f =       135.63  |proj g|=    2.5144e-06
#
# iterations 6
# function evaluations 10
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 2.51436e-06
# final function value 135.628
#
# F = 135.628
# final  value 135.628221
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.78277 19.31373
#   - best initial criterion value(s) :  -140.282
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       140.28  |proj g|=      0.18416
# At iterate     1  f =       140.25  |proj g|=         0.169
# At iterate     2  f =       139.84  |proj g|=     0.0094074
# Nonpositive definiteness in Cholesky factorization in formk;
#    refresh the lbfgs memory and restart the iteration.
# At iterate     3  f =       139.84  |proj g|=     0.0062672
# At iterate     4  f =       139.83  |proj g|=    7.2877e-05
# At iterate     5  f =       139.83  |proj g|=     5.543e-07
#
# iterations 5
# function evaluations 7
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.54304e-07
# final function value 139.835
#
# F = 139.835
# final  value 139.834752
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.65762 19.14898
#   - best initial criterion value(s) :  -142.7917
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       142.79  |proj g|=      0.69223
# At iterate     1  f =       142.27  |proj g|=       0.54216
# At iterate     2  f =       141.38  |proj g|=         0.121
# At iterate     3  f =       141.27  |proj g|=       0.10961
# At iterate     4  f =       140.89  |proj g|=       0.10825
# At iterate     5  f =       140.87  |proj g|=             0
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 140.868
#
# F = 140.868
# final  value 140.867676
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.65762 19.14898
#   - best initial criterion value(s) :  -136.9349
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       136.93  |proj g|=       0.4744
# At iterate     1  f =       136.75  |proj g|=       0.25787
# At iterate     2  f =       136.62  |proj g|=       0.18762
# At iterate     3  f =       136.46  |proj g|=       0.28476
# At iterate     4  f =       135.98  |proj g|=       0.35052
# At iterate     5  f =       135.78  |proj g|=      0.077539
# At iterate     6  f =       135.76  |proj g|=       0.00129
# At iterate     7  f =       135.76  |proj g|=    2.9034e-05
# At iterate     8  f =       135.76  |proj g|=    1.2971e-08
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 9
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.29707e-08
# final function value 135.76
#
# F = 135.76
# final  value 135.760418
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.65762 19.14898
#   - best initial criterion value(s) :  -141.1851
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       141.19  |proj g|=      0.19681
# At iterate     1  f =       141.15  |proj g|=       0.17607
# At iterate     2  f =       140.93  |proj g|=       0.10695
# At iterate     3  f =       140.89  |proj g|=      0.073693
# At iterate     4  f =       140.87  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 140.868
#
# F = 140.868
# final  value 140.867676
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.23622 18.58538
#   - best initial criterion value(s) :  -145.7097
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       145.71  |proj g|=      0.24999
# At iterate     1  f =       145.62  |proj g|=       0.23668
# At iterate     2  f =       144.46  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 144.46
#
# F = 144.46
# final  value 144.459698
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.23622 18.58538
#   - best initial criterion value(s) :  -143.2008
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        143.2  |proj g|=      0.45113
# At iterate     1  f =       143.02  |proj g|=       0.34275
# At iterate     2  f =       142.75  |proj g|=        0.1461
# At iterate     3  f =       142.72  |proj g|=      0.096406
# At iterate     4  f =       142.69  |proj g|=     0.0064154
# At iterate     5  f =       142.69  |proj g|=    0.00031474
# At iterate     6  f =       142.69  |proj g|=    1.1136e-06
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.11355e-06
# final function value 142.693
#
# F = 142.693
# final  value 142.693027
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.23622 18.58538
#   - best initial criterion value(s) :  -145.5642
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       145.56  |proj g|=      0.30046
# At iterate     1  f =       145.47  |proj g|=       0.27355
# At iterate     2  f =       144.55  |proj g|=       0.12513
# At iterate     3  f =       144.46  |proj g|=             0
#
# iterations 3
# function evaluations 4
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 144.46
#
# F = 144.46
# final  value 144.459698
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.36695 18.31292
#   - best initial criterion value(s) :  -136.8139
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       136.81  |proj g|=      0.51113
# At iterate     1  f =       136.53  |proj g|=       0.39748
# At iterate     2  f =       136.08  |proj g|=      0.095581
# At iterate     3  f =       135.97  |proj g|=       0.12725
# At iterate     4  f =       135.61  |proj g|=       0.11169
# At iterate     5  f =       135.58  |proj g|=             0
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 135.582
#
# F = 135.582
# final  value 135.581842
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.36695 18.31292
#   - best initial criterion value(s) :  -132.4891
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       132.49  |proj g|=      0.32856
# At iterate     1  f =        132.4  |proj g|=       0.20676
# At iterate     2  f =       132.27  |proj g|=       0.20117
# At iterate     3  f =       132.07  |proj g|=       0.29965
# At iterate     4  f =       131.86  |proj g|=       0.24785
# At iterate     5  f =       131.75  |proj g|=      0.077194
# At iterate     6  f =       131.74  |proj g|=             0
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 131.738
#
# F = 131.738
# final  value 131.737818
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.36695 18.31292
#   - best initial criterion value(s) :  -135.8851
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       135.89  |proj g|=      0.11821
# At iterate     1  f =       135.87  |proj g|=       0.10975
# At iterate     2  f =        135.6  |proj g|=      0.077541
# At iterate     3  f =       135.58  |proj g|=             0
#
# iterations 3
# function evaluations 4
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 135.582
#
# F = 135.582
# final  value 135.581842
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.01206 19.375
#   - best initial criterion value(s) :  -134.9015
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        134.9  |proj g|=      0.31243
# At iterate     1  f =       134.81  |proj g|=       0.26746
# At iterate     2  f =       134.22  |proj g|=       0.18594
# At iterate     3  f =       133.88  |proj g|=       0.12249
# At iterate     4  f =       133.81  |proj g|=      0.033054
# At iterate     5  f =        133.8  |proj g|=     0.0022187
# At iterate     6  f =        133.8  |proj g|=     4.601e-05
# At iterate     7  f =        133.8  |proj g|=     6.668e-08
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 6.66802e-08
# final function value 133.799
#
# F = 133.799
# final  value 133.799053
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.01206 19.375
#   - best initial criterion value(s) :  -132.8898
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       132.89  |proj g|=        1.067
# At iterate     1  f =       132.01  |proj g|=        0.4454
# At iterate     2  f =       131.71  |proj g|=       0.26994
# At iterate     3  f =        131.2  |proj g|=       0.41966
# At iterate     4  f =       130.39  |proj g|=       0.39407
# At iterate     5  f =       130.04  |proj g|=      0.041827
# At iterate     6  f =       130.03  |proj g|=     0.0032232
# At iterate     7  f =       130.03  |proj g|=    3.4808e-05
# At iterate     8  f =       130.03  |proj g|=    3.4819e-05
#
# iterations 8
# function evaluations 16
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.4819e-05
# final function value 130.034
#
# F = 130.034
# final  value 130.034030
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.01206 19.375
#   - best initial criterion value(s) :  -134.5718
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       134.57  |proj g|=      0.28765
# At iterate     1  f =       134.49  |proj g|=       0.24978
# At iterate     2  f =       133.99  |proj g|=       0.16351
# At iterate     3  f =       133.87  |proj g|=       0.11417
# At iterate     4  f =        133.8  |proj g|=      0.014397
# At iterate     5  f =        133.8  |proj g|=    0.00092818
# At iterate     6  f =        133.8  |proj g|=    8.5879e-06
# At iterate     7  f =        133.8  |proj g|=     5.209e-09
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.20897e-09
# final function value 133.799
#
# F = 133.799
# final  value 133.799053
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.44844 17.42009
#   - best initial criterion value(s) :  -133.9431
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       133.94  |proj g|=       1.0764
# At iterate     1  f =       132.76  |proj g|=       0.75359
# At iterate     2  f =       131.49  |proj g|=       0.20266
# At iterate     3  f =       131.25  |proj g|=       0.17446
# At iterate     4  f =       130.56  |proj g|=       0.11673
# At iterate     5  f =        130.5  |proj g|=      0.024458
# At iterate     6  f =       130.49  |proj g|=     0.0024364
# At iterate     7  f =       130.49  |proj g|=    5.7419e-05
# At iterate     8  f =       130.49  |proj g|=    1.3868e-07
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.38678e-07
# final function value 130.494
#
# F = 130.494
# final  value 130.493858
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.44844 17.42009
#   - best initial criterion value(s) :  -128.1652
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       128.17  |proj g|=      0.46624
# At iterate     1  f =       127.98  |proj g|=       0.28594
# At iterate     2  f =       127.82  |proj g|=       0.14564
# At iterate     3  f =       127.68  |proj g|=       0.21639
# At iterate     4  f =       127.56  |proj g|=      0.036738
# At iterate     5  f =       127.55  |proj g|=     0.0050864
# At iterate     6  f =       127.55  |proj g|=    0.00011411
# At iterate     7  f =       127.55  |proj g|=    3.6258e-07
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.62581e-07
# final function value 127.555
#
# F = 127.555
# final  value 127.554891
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.44844 17.42009
#   - best initial criterion value(s) :  -131.7141
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       131.71  |proj g|=      0.29514
# At iterate     1  f =       131.63  |proj g|=       0.24568
# At iterate     2  f =       130.97  |proj g|=       0.20624
# At iterate     3  f =       130.52  |proj g|=      0.076779
# At iterate     4  f =        130.5  |proj g|=      0.029285
# At iterate     5  f =       130.49  |proj g|=     0.0019876
# At iterate     6  f =       130.49  |proj g|=     5.581e-05
# At iterate     7  f =       130.49  |proj g|=    1.1002e-07
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.10015e-07
# final function value 130.494
#
# F = 130.494
# final  value 130.493858
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.89999 18.66941
#   - best initial criterion value(s) :  -135.7462
#
# ...
# At iterate     5  f =       127.54  |proj g|=      0.013269
# At iterate     6  f =       127.54  |proj g|=     0.0006097
# At iterate     7  f =       127.54  |proj g|=    4.1012e-06
# At iterate     8  f =       127.54  |proj g|=    1.9952e-09
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.99519e-09
# final function value 127.543
#
# F = 127.543
# final  value 127.542802
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.81778 18.76201
#   - best initial criterion value(s) :  -134.3155
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       134.32  |proj g|=      0.42519
# At iterate     1  f =       134.12  |proj g|=       0.37255
# At iterate     2  f =       133.42  |proj g|=      0.087499
# At iterate     3  f =       133.29  |proj g|=      0.090789
# At iterate     4  f =       133.11  |proj g|=      0.037536
# At iterate     5  f =        133.1  |proj g|=             0
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 133.102
#
# F = 133.102
# final  value 133.102134
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.02831 18.12636
#   - best initial criterion value(s) :  -134.6849
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       134.68  |proj g|=      0.46838
# At iterate     1  f =       134.44  |proj g|=       0.35869
# At iterate     2  f =       134.08  |proj g|=      0.064394
# At iterate     3  f =       134.05  |proj g|=      0.079105
# At iterate     4  f =       133.79  |proj g|=      0.023803
# At iterate     5  f =       133.79  |proj g|=    0.00049101
# At iterate     6  f =       133.79  |proj g|=    8.8708e-06
# At iterate     7  f =       133.79  |proj g|=    3.4022e-09
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.4022e-09
# final function value 133.789
#
# F = 133.789
# final  value 133.789239
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.02831 18.12636
#   - best initial criterion value(s) :  -130.0985
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        130.1  |proj g|=       0.7508
# At iterate     1  f =       129.65  |proj g|=       0.29297
# At iterate     2  f =       129.53  |proj g|=       0.20865
# At iterate     3  f =       129.29  |proj g|=       0.34572
# At iterate     4  f =       128.73  |proj g|=       0.41039
# At iterate     5  f =       128.54  |proj g|=       0.25218
# At iterate     6  f =       128.42  |proj g|=      0.028714
# At iterate     7  f =       128.41  |proj g|=             0
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 128.415
#
# F = 128.415
# final  value 128.414514
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.02831 18.12636
#   - best initial criterion value(s) :  -133.8473
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       133.85  |proj g|=      0.14791
# At iterate     1  f =       133.82  |proj g|=       0.12814
# At iterate     2  f =       133.79  |proj g|=     0.0011939
# At iterate     3  f =       133.79  |proj g|=     0.0007665
# At iterate     4  f =       133.79  |proj g|=    7.1203e-07
# At iterate     5  f =       133.79  |proj g|=    4.2773e-10
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 4.27728e-10
# final function value 133.789
#
# F = 133.789
# final  value 133.789239
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.12984 19.41829
#   - best initial criterion value(s) :  -141.6796
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       141.68  |proj g|=      0.38982
# At iterate     1  f =        141.5  |proj g|=       0.32645
# At iterate     2  f =       141.09  |proj g|=      0.084349
# At iterate     3  f =       141.01  |proj g|=       0.10328
# At iterate     4  f =       140.87  |proj g|=      0.042803
# At iterate     5  f =       140.86  |proj g|=     0.0053205
# At iterate     6  f =       140.86  |proj g|=    0.00020985
# At iterate     7  f =       140.86  |proj g|=    1.0927e-06
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.09267e-06
# final function value 140.86
#
# F = 140.86
# final  value 140.859766
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.12984 19.41829
#   - best initial criterion value(s) :  -136.6674
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       136.67  |proj g|=      0.33602
# At iterate     1  f =       136.57  |proj g|=       0.21893
# At iterate     2  f =       136.41  |proj g|=       0.22234
# At iterate     3  f =       136.15  |proj g|=       0.31428
# At iterate     4  f =        135.8  |proj g|=      0.080494
# At iterate     5  f =       135.79  |proj g|=      0.019623
# At iterate     6  f =       135.78  |proj g|=    0.00054025
# At iterate     7  f =       135.78  |proj g|=    3.4258e-06
# At iterate     8  f =       135.78  |proj g|=    3.4258e-06
#
# iterations 8
# function evaluations 21
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.42579e-06
# final function value 135.784
#
# F = 135.784
# l(0) > u(0).  No feasible solutionfinal  value 135.784270
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.12984 19.41829
#   - best initial criterion value(s) :  -142.2362
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       142.24  |proj g|=      0.19755
# At iterate     1  f =        142.2  |proj g|=       0.16348
# At iterate     2  f =       141.85  |proj g|=       0.20373
# At iterate     3  f =       141.21  |proj g|=       0.22453
# At iterate     4  f =       140.89  |proj g|=      0.075678
# At iterate     5  f =       140.86  |proj g|=     0.0049293
# At iterate     6  f =       140.86  |proj g|=    0.00032933
# At iterate     7  f =       140.86  |proj g|=    1.5894e-06
# At iterate     8  f =       140.86  |proj g|=    5.1669e-10
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.16692e-10
# final function value 140.86
#
# F = 140.86
# final  value 140.859766
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  17.69997 18.22512
#   - best initial criterion value(s) :  -131.1619
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       131.16  |proj g|=      0.59727
# At iterate     1  f =       130.85  |proj g|=       0.41724
# At iterate     2  f =       130.39  |proj g|=       0.22538
# At iterate     3  f =       129.96  |proj g|=       0.29272
# At iterate     4  f =       129.01  |proj g|=       0.20749
# At iterate     5  f =       128.82  |proj g|=      0.052848
# At iterate     6  f =       128.81  |proj g|=     0.0085457
# At iterate     7  f =       128.81  |proj g|=    0.00044602
# At iterate     8  f =       128.81  |proj g|=    4.0527e-06
# Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# Line search cannot locate an adequate point after 20 function
# and gradient evaluations
# final  value 128.806559
# stopped after 8 iterations
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  17.69997 18.22512
#   - best initial criterion value(s) :  -125.3268
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       125.33  |proj g|=      0.32669
# At iterate     1  f =       125.23  |proj g|=       0.23509
# At iterate     2  f =       125.12  |proj g|=      0.087925
# At iterate     3  f =       125.11  |proj g|=       0.06226
# At iterate     4  f =       125.11  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 125.107
#
# F = 125.107
# final  value 125.107220
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  17.69997 18.22512
#   - best initial criterion value(s) :  -130.0585
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       130.06  |proj g|=      0.35823
# At iterate     1  f =       129.94  |proj g|=       0.29192
# At iterate     2  f =       129.55  |proj g|=       0.17489
# At iterate     3  f =       129.18  |proj g|=       0.22207
# At iterate     4  f =       128.89  |proj g|=       0.12406
# At iterate     5  f =       128.81  |proj g|=      0.025651
# At iterate     6  f =       128.81  |proj g|=     0.0028087
# At iterate     7  f =       128.81  |proj g|=    7.4478e-05
# At iterate     8  f =       128.81  |proj g|=    2.2445e-07
#
# iterations 8
# function evaluations 9
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 2.24446e-07
# final function value 128.807
#
# F = 128.807
# final  value 128.806559
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.98028 17.69471
#   - best initial criterion value(s) :  -120.968
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       120.97  |proj g|=      0.36102
# At iterate     1  f =       120.82  |proj g|=       0.26056
# At iterate     2  f =       120.65  |proj g|=      0.067694
# At iterate     3  f =       120.62  |proj g|=      0.086573
# At iterate     4  f =       120.47  |proj g|=      0.094334
# At iterate     5  f =       120.39  |proj g|=      0.032579
# At iterate     6  f =       120.39  |proj g|=      0.014469
# At iterate     7  f =       120.39  |proj g|=    0.00034114
# At iterate     8  f =       120.39  |proj g|=    3.7079e-06
# At iterate     9  f =       120.39  |proj g|=     9.657e-10
#
# iterations 9
# function evaluations 10
# segments explored during Cauchy searches 9
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 9.65704e-10
# final function value 120.386
#
# F = 120.386
# final  value 120.386279
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.98028 17.69471
#   - best initial criterion value(s) :  -116.4756
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       116.48  |proj g|=       1.1553
# At iterate     1  f =       115.38  |proj g|=       0.41049
# At iterate     2  f =       115.19  |proj g|=       0.22362
# At iterate     3  f =       115.02  |proj g|=       0.32375
# At iterate     4  f =       114.42  |proj g|=       0.40329
# At iterate     5  f =       114.05  |proj g|=       0.10834
# At iterate     6  f =       114.03  |proj g|=      0.031405
# At iterate     7  f =       114.03  |proj g|=    0.00093243
# At iterate     8  f =       114.03  |proj g|=    7.4494e-06
# At iterate     9  f =       114.03  |proj g|=    7.3844e-06
#
# iterations 9
# function evaluations 16
# segments explored during Cauchy searches 9
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 7.38444e-06
# final function value 114.029
#
# F = 114.029
# final  value 114.029471
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.98028 17.69471
#   - best initial criterion value(s) :  -120.4013
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        120.4  |proj g|=     0.024048
# At iterate     1  f =        120.4  |proj g|=      0.021812
# At iterate     2  f =       120.39  |proj g|=      0.025429
# At iterate     3  f =       120.39  |proj g|=      0.001469
# At iterate     4  f =       120.39  |proj g|=    8.9514e-05
# At iterate     5  f =       120.39  |proj g|=    1.0072e-07
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.0072e-07
# final function value 120.386
#
# F = 120.386
# final  value 120.386279
# converged

# %%
bla_2 = do.call(rbind, out_2)

p = ggplot(data = bla_2, aes(x = misspec, y = neg_loglik, colour = type)) + geom_boxplot() #+ ylim(c(0, 50))
p
# Out:
# plot without title

# %%
# Create a Table 
bla_2_s = setDT(bla_2)[, .(mean(neg_loglik), sd(neg_loglik)), by = c("misspec", "type", "dimension")]

# %%
bla_2_s$variant = paste0(bla_2_s$type, "_", bla_2_s$misspec)
bla_2_s$value = paste0(round(bla_2_s$V1, 2), " (", round(bla_2_s$V2, 2), ")")

# %%
reshape2::dcast(bla_2_s, formula = dimension ~ variant, value.var = "value")
# Out:
#   dimension pdp_var_FALSE pdp_var_gp_FALSE pdp_var_gp_TRUE pdp_var_TRUE
# 1 2         3.15 (0.38)   2.51 (0.49)      2.34 (1.36)     2.64 (0.76)

# %%
out_5 = lapply(seq_len(50), function(i) {
        res = simulate_kernel(dimension = 5, true_kernel = "matern3_2", wrong_kernel = "matern5_2", n = 30)
        res$iter = i
    
        res
})
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.7852 19.22764 18.60986 18.74395 18.76872
#   - best initial criterion value(s) :  -164.3145
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       164.31  |proj g|=       0.4809
# At iterate     1  f =       164.19  |proj g|=       0.63186
# At iterate     2  f =       164.09  |proj g|=       0.66249
# At iterate     3  f =       163.95  |proj g|=       0.22444
# At iterate     4  f =       163.78  |proj g|=       0.16338
# At iterate     5  f =       163.61  |proj g|=       0.23253
# At iterate     6  f =       163.54  |proj g|=        0.6765
# At iterate     7  f =       163.46  |proj g|=       0.45843
# At iterate     8  f =       163.31  |proj g|=       0.16976
# At iterate     9  f =       163.28  |proj g|=       0.17108
# At iterate    10  f =       163.17  |proj g|=       0.14433
# At iterate    11  f =        163.1  |proj g|=       0.23013
# At iterate    12  f =       163.05  |proj g|=       0.02424
# At iterate    13  f =       163.05  |proj g|=      0.017722
# At iterate    14  f =       163.05  |proj g|=      0.017483
# At iterate    15  f =       163.05  |proj g|=      0.034914
# At iterate    16  f =       163.05  |proj g|=      0.066077
# At iterate    17  f =       163.04  |proj g|=      0.078165
# At iterate    18  f =       163.04  |proj g|=       0.12109
# At iterate    19  f =       163.02  |proj g|=       0.05658
# At iterate    20  f =       163.02  |proj g|=      0.048113
# At iterate    21  f =       163.02  |proj g|=     0.0097078
# At iterate    22  f =       163.02  |proj g|=     0.0068574
# At iterate    23  f =       163.02  |proj g|=     0.0076323
# At iterate    24  f =       163.02  |proj g|=      0.011557
# At iterate    25  f =       163.02  |proj g|=      0.014453
# At iterate    26  f =       163.02  |proj g|=       0.02515
# At iterate    27  f =       163.02  |proj g|=      0.018899
# At iterate    28  f =       163.01  |proj g|=      0.012706
# At iterate    29  f =       163.01  |proj g|=     0.0034589
# At iterate    30  f =       163.01  |proj g|=     0.0026723
# At iterate    31  f =       163.01  |proj g|=     0.0013427
# At iterate    32  f =       163.01  |proj g|=    0.00092421
# At iterate    33  f =       163.01  |proj g|=    0.00018533
#
# iterations 33
# function evaluations 41
# segments explored during Cauchy searches 33
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.000185325
# final function value 163.015
#
# F = 163.015
# final  value 163.014870
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.7852 19.22764 18.60986 18.74395 18.76872
#   - best initial criterion value(s) :  -163.2667
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       163.27  |proj g|=      0.70738
# At iterate     1  f =       163.12  |proj g|=       0.35038
# At iterate     2  f =       163.07  |proj g|=       0.27295
# At iterate     3  f =       162.98  |proj g|=        0.1591
# At iterate     4  f =       162.91  |proj g|=       0.17091
# At iterate     5  f =       162.85  |proj g|=       0.39654
# At iterate     6  f =       162.84  |proj g|=        0.2465
# At iterate     7  f =       162.83  |proj g|=      0.039255
# At iterate     8  f =       162.83  |proj g|=      0.034291
# At iterate     9  f =       162.83  |proj g|=       0.10648
# At iterate    10  f =       162.82  |proj g|=       0.20232
# At iterate    11  f =       162.81  |proj g|=        0.2219
# At iterate    12  f =       162.81  |proj g|=      0.055202
# At iterate    13  f =        162.8  |proj g|=      0.039472
# At iterate    14  f =        162.8  |proj g|=      0.056241
# At iterate    15  f =        162.8  |proj g|=      0.013282
# At iterate    16  f =        162.8  |proj g|=      0.044607
# At iterate    17  f =        162.8  |proj g|=      0.031068
# At iterate    18  f =        162.8  |proj g|=      0.096954
# At iterate    19  f =        162.8  |proj g|=       0.10653
# At iterate    20  f =        162.8  |proj g|=      0.084698
# At iterate    21  f =       162.79  |proj g|=     0.0083277
# At iterate    22  f =       162.79  |proj g|=     0.0083612
# At iterate    23  f =       162.79  |proj g|=      0.016749
# At iterate    24  f =       162.79  |proj g|=      0.031368
# At iterate    25  f =       162.79  |proj g|=      0.063063
# At iterate    26  f =       162.79  |proj g|=      0.055922
# At iterate    27  f =       162.79  |proj g|=       0.14898
# At iterate    28  f =       162.79  |proj g|=       0.10832
# At iterate    29  f =       162.78  |proj g|=      0.056669
# At iterate    30  f =        162.2  |proj g|=        1.9864
# At iterate    31  f =        162.2  |proj g|=        1.9839
# At iterate    32  f =       162.06  |proj g|=       0.44109
# At iterate    33  f =       161.67  |proj g|=       0.42359
# At iterate    34  f =       161.03  |proj g|=       0.08983
# At iterate    35  f =       160.99  |proj g|=       0.15128
# At iterate    36  f =       160.93  |proj g|=       0.26097
# At iterate    37  f =        160.9  |proj g|=       0.13894
# At iterate    38  f =       160.89  |proj g|=       0.20831
# At iterate    39  f =       160.89  |proj g|=      0.017203
# At iterate    40  f =       160.89  |proj g|=     0.0064575
# At iterate    41  f =       160.89  |proj g|=     0.0022607
# At iterate    42  f =       160.89  |proj g|=      0.002251
# At iterate    43  f =       160.89  |proj g|=     0.0046799
# At iterate    44  f =       160.89  |proj g|=      0.010053
# At iterate    45  f =       160.89  |proj g|=      0.014561
# At iterate    46  f =       160.89  |proj g|=      0.043475
# At iterate    47  f =       160.89  |proj g|=      0.030937
# At iterate    48  f =       160.89  |proj g|=     0.0059485
# At iterate    49  f =       160.89  |proj g|=     0.0042607
# At iterate    50  f =       160.89  |proj g|=     0.0017313
# At iterate    51  f =       160.89  |proj g|=     0.0005434
# At iterate    52  f =       160.89  |proj g|=     0.0012558
#
# iterations 52
# function evaluations 65
# segments explored during Cauchy searches 52
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.00125576
# final function value 160.886
#
# F = 160.886
# final  value 160.885502
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.7852 19.22764 18.60986 18.74395 18.76872
#   - best initial criterion value(s) :  -163.5412
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       163.54  |proj g|=       1.4533
# At iterate     1  f =       163.06  |proj g|=        1.1443
# At iterate     2  f =       162.86  |proj g|=       0.98969
# At iterate     3  f =       162.64  |proj g|=       0.22861
# At iterate     4  f =       162.64  |proj g|=       0.19386
# At iterate     5  f =       162.63  |proj g|=      0.055317
# At iterate     6  f =       162.63  |proj g|=      0.056009
# At iterate     7  f =       162.61  |proj g|=       0.22311
# At iterate     8  f =       162.58  |proj g|=       0.35157
# At iterate     9  f =       161.65  |proj g|=       0.28155
# At iterate    10  f =       161.64  |proj g|=       0.28668
# At iterate    11  f =       161.62  |proj g|=       0.32623
# At iterate    12  f =        161.6  |proj g|=       0.31302
# At iterate    13  f =       161.44  |proj g|=       0.16008
# At iterate    14  f =        161.3  |proj g|=       0.11274
# At iterate    15  f =       161.22  |proj g|=      0.023316
# At iterate    16  f =       161.21  |proj g|=      0.012664
# At iterate    17  f =       161.21  |proj g|=      0.047661
# At iterate    18  f =        161.2  |proj g|=      0.028338
# At iterate    19  f =       161.19  |proj g|=      0.044367
# At iterate    20  f =       161.18  |proj g|=      0.019628
# At iterate    21  f =       161.18  |proj g|=      0.024458
# At iterate    22  f =       161.17  |proj g|=       0.01603
# At iterate    23  f =       161.17  |proj g|=      0.050183
# At iterate    24  f =       161.17  |proj g|=      0.014115
# At iterate    25  f =       161.17  |proj g|=     0.0019359
# At iterate    26  f =       161.17  |proj g|=    0.00030425
# At iterate    27  f =       161.17  |proj g|=    2.8183e-05
#
# iterations 27
# function evaluations 39
# segments explored during Cauchy searches 29
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.81825e-05
# final function value 161.168
#
# F = 161.168
# final  value 161.168415
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.71602 18.07912 19.88924 18.16566 19.10527
#   - best initial criterion value(s) :  -169.0951
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        169.1  |proj g|=      0.50099
# At iterate     1  f =       168.77  |proj g|=       0.39143
# At iterate     2  f =       167.79  |proj g|=       0.58905
# At iterate     3  f =       167.42  |proj g|=       0.18867
# At iterate     4  f =        167.3  |proj g|=       0.11922
# At iterate     5  f =       167.06  |proj g|=       0.15934
# At iterate     6  f =       166.84  |proj g|=       0.44811
# At iterate     7  f =        166.7  |proj g|=       0.13441
# At iterate     8  f =       166.54  |proj g|=       0.25754
# At iterate     9  f =       166.51  |proj g|=       0.11367
# At iterate    10  f =       166.51  |proj g|=      0.040328
# At iterate    11  f =       166.51  |proj g|=      0.014545
# At iterate    12  f =       166.51  |proj g|=      0.014694
# At iterate    13  f =        166.5  |proj g|=      0.056231
# At iterate    14  f =        166.5  |proj g|=      0.039068
# At iterate    15  f =        166.5  |proj g|=     0.0057365
# At iterate    16  f =        166.5  |proj g|=     0.0062557
# At iterate    17  f =        166.5  |proj g|=     0.0087675
# At iterate    18  f =        166.5  |proj g|=     0.0020214
# At iterate    19  f =        166.5  |proj g|=    0.00020706
# At iterate    20  f =        166.5  |proj g|=    4.5148e-06
#
# iterations 20
# function evaluations 22
# segments explored during Cauchy searches 20
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 4.51476e-06
# final function value 166.5
#
# F = 166.5
# final  value 166.499961
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.71602 18.07912 19.88924 18.16566 19.10527
#   - best initial criterion value(s) :  -168.0865
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       168.09  |proj g|=      0.84485
# At iterate     1  f =       167.21  |proj g|=        0.7365
# At iterate     2  f =       166.96  |proj g|=       0.23141
# At iterate     3  f =       166.89  |proj g|=       0.38448
# At iterate     4  f =       166.65  |proj g|=        0.3676
# At iterate     5  f =       166.52  |proj g|=       0.10386
# At iterate     6  f =        166.5  |proj g|=       0.19615
# At iterate     7  f =       166.45  |proj g|=        0.2724
# At iterate     8  f =       166.41  |proj g|=      0.098146
# At iterate     9  f =       166.39  |proj g|=      0.045104
# At iterate    10  f =       166.38  |proj g|=       0.20579
# At iterate    11  f =       166.37  |proj g|=      0.067711
# At iterate    12  f =       166.37  |proj g|=      0.029228
# At iterate    13  f =       166.23  |proj g|=       0.11669
# ys=-1.866e-01  -gs= 6.915e-02, BFGS update SKIPPED
# At iterate    14  f =       166.23  |proj g|=      0.081395
# At iterate    15  f =       166.22  |proj g|=      0.079514
# At iterate    16  f =       166.22  |proj g|=      0.083223
# At iterate    17  f =       166.21  |proj g|=       0.11204
# At iterate    18  f =       166.18  |proj g|=      0.096273
# At iterate    19  f =       165.46  |proj g|=        1.1715
# At iterate    20  f =       165.45  |proj g|=        1.1579
# At iterate    21  f =       165.41  |proj g|=       0.87054
# At iterate    22  f =       165.37  |proj g|=      0.043946
# At iterate    23  f =       165.37  |proj g|=      0.039903
# At iterate    24  f =       165.36  |proj g|=      0.026749
# At iterate    25  f =       165.36  |proj g|=     0.0030828
# At iterate    26  f =       165.36  |proj g|=    0.00052618
# At iterate    27  f =       165.36  |proj g|=     5.466e-05
#
# iterations 27
# function evaluations 38
# segments explored during Cauchy searches 28
# BFGS updates skipped 1
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 5.46599e-05
# final function value 165.358
#
# F = 165.358
# final  value 165.357544
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.71602 18.07912 19.88924 18.16566 19.10527
#   - best initial criterion value(s) :  -168.2325
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       168.23  |proj g|=       0.5647
# At iterate     1  f =       167.79  |proj g|=       0.38281
# At iterate     2  f =        167.5  |proj g|=        0.7348
# At iterate     3  f =       167.31  |proj g|=      0.093099
# At iterate     4  f =       167.29  |proj g|=      0.076864
# At iterate     5  f =       167.27  |proj g|=       0.05372
# At iterate     6  f =       167.23  |proj g|=      0.077579
# At iterate     7  f =       167.08  |proj g|=       0.38891
# At iterate     8  f =       167.05  |proj g|=       0.59612
# At iterate     9  f =       166.98  |proj g|=       0.10352
# At iterate    10  f =       166.95  |proj g|=       0.10509
# At iterate    11  f =       166.84  |proj g|=      0.094405
# At iterate    12  f =       166.73  |proj g|=       0.36021
# At iterate    13  f =       166.37  |proj g|=         1.599
# At iterate    14  f =       166.34  |proj g|=        1.5343
# At iterate    15  f =       166.17  |proj g|=        0.3708
# At iterate    16  f =       166.16  |proj g|=      0.050236
# At iterate    17  f =       166.16  |proj g|=     0.0053576
# At iterate    18  f =       166.16  |proj g|=     0.0051118
# At iterate    19  f =       166.16  |proj g|=     0.0091292
# At iterate    20  f =       166.16  |proj g|=      0.014288
# At iterate    21  f =       166.16  |proj g|=      0.011292
# At iterate    22  f =       166.16  |proj g|=     0.0033806
# At iterate    23  f =       166.16  |proj g|=    0.00066565
# At iterate    24  f =       166.16  |proj g|=    5.2883e-06
#
# iterations 24
# function evaluations 33
# segments explored during Cauchy searches 24
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 5.28828e-06
# final function value 166.157
#
# F = 166.157
# final  value 166.157020
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  17.06171 18.3129 18.22092 18.02606 17.52427
#   - best initial criterion value(s) :  -164.9205
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       164.92  |proj g|=      0.26843
# At iterate     1  f =       164.68  |proj g|=         0.826
# ys=-1.254e-01  -gs= 1.863e-01, BFGS update SKIPPED
# At iterate     2  f =       164.08  |proj g|=      0.094017
# At iterate     3  f =       164.08  |proj g|=       0.17069
# At iterate     4  f =          164  |proj g|=       0.22025
# At iterate     5  f =       163.64  |proj g|=      0.069498
# At iterate     6  f =       163.21  |proj g|=       0.08045
# At iterate     7  f =       163.17  |proj g|=        0.1749
# At iterate     8  f =       163.16  |proj g|=       0.25234
# At iterate     9  f =       163.15  |proj g|=        0.1938
# At iterate    10  f =       163.15  |proj g|=      0.049514
# At iterate    11  f =       163.15  |proj g|=      0.019618
# At iterate    12  f =       163.14  |proj g|=       0.15115
# At iterate    13  f =       163.13  |proj g|=       0.43413
# At iterate    14  f =       163.11  |proj g|=       0.96327
# At iterate    15  f =       163.04  |proj g|=         1.864
# At iterate    16  f =          163  |proj g|=        3.0833
# At iterate    17  f =       162.88  |proj g|=        2.9685
# At iterate    18  f =       161.76  |proj g|=        0.2273
# At iterate    19  f =       161.72  |proj g|=       0.10931
# At iterate    20  f =        161.7  |proj g|=      0.029305
# At iterate    21  f =       161.69  |proj g|=      0.036574
# At iterate    22  f =       161.69  |proj g|=       0.02107
# At iterate    23  f =       161.69  |proj g|=     0.0074227
# At iterate    24  f =       161.69  |proj g|=    0.00085009
# At iterate    25  f =       161.69  |proj g|=    0.00025852
# At iterate    26  f =       161.69  |proj g|=    1.6363e-05
#
# iterations 26
# function evaluations 45
# segments explored during Cauchy searches 26
# BFGS updates skipped 1
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 1.63632e-05
# final function value 161.694
#
# F = 161.694
# final  value 161.694092
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  17.06171 18.3129 18.22092 18.02606 17.52427
#   - best initial criterion value(s) :  -163.4314
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       163.43  |proj g|=       1.8926
# At iterate     1  f =       163.12  |proj g|=       0.42613
# At iterate     2  f =       163.07  |proj g|=       0.21152
# At iterate     3  f =       163.04  |proj g|=       0.20134
# At iterate     4  f =       163.02  |proj g|=        0.1991
# At iterate     5  f =       162.86  |proj g|=       0.81707
# At iterate     6  f =       162.71  |proj g|=       0.57494
# At iterate     7  f =       162.55  |proj g|=      0.075884
# At iterate     8  f =        162.5  |proj g|=      0.032361
# At iterate     9  f =       162.45  |proj g|=        0.1121
# At iterate    10  f =       162.39  |proj g|=      0.061974
# At iterate    11  f =       162.38  |proj g|=      0.040505
# At iterate    12  f =       162.36  |proj g|=       0.26644
# At iterate    13  f =       162.31  |proj g|=       0.59584
# At iterate    14  f =       162.27  |proj g|=       0.74325
# At iterate    15  f =       162.23  |proj g|=       0.39742
# At iterate    16  f =       162.22  |proj g|=       0.18479
# At iterate    17  f =       162.21  |proj g|=      0.061091
# At iterate    18  f =        162.2  |proj g|=       0.11304
# At iterate    19  f =        162.2  |proj g|=       0.17593
# At iterate    20  f =       162.17  |proj g|=       0.29763
# At iterate    21  f =        162.1  |proj g|=       0.15748
# At iterate    22  f =       162.07  |proj g|=      0.057936
# At iterate    23  f =       161.97  |proj g|=      0.047262
# At iterate    24  f =       161.94  |proj g|=       0.16204
# At iterate    25  f =       161.84  |proj g|=      0.053704
# At iterate    26  f =       161.84  |proj g|=      0.012578
# At iterate    27  f =       161.84  |proj g|=     0.0010694
# At iterate    28  f =       161.84  |proj g|=    0.00019772
# At iterate    29  f =       161.84  |proj g|=    6.4309e-05
#
# iterations 29
# function evaluations 34
# segments explored during Cauchy searches 29
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 6.43091e-05
# final function value 161.843
#
# F = 161.843
# final  value 161.842593
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  17.06171 18.3129 18.22092 18.02606 17.52427
#   - best initial criterion value(s) :  -164.655
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       164.65  |proj g|=      0.33937
# At iterate     1  f =       164.65  |proj g|=       0.22327
# At iterate     2  f =       164.65  |proj g|=       0.13099
# At iterate     3  f =       164.65  |proj g|=       0.13007
# At iterate     4  f =       164.65  |proj g|=       0.41508
# At iterate     5  f =       164.64  |proj g|=        0.9144
# At iterate     6  f =       164.62  |proj g|=        1.7354
# At iterate     7  f =       164.56  |proj g|=         2.952
# At iterate     8  f =       164.41  |proj g|=        4.2466
# At iterate     9  f =       164.11  |proj g|=        3.9406
# At iterate    10  f =       163.98  |proj g|=       0.34501
# At iterate    11  f =       163.85  |proj g|=       0.29253
# At iterate    12  f =       163.83  |proj g|=        1.0089
# At iterate    13  f =       163.83  |proj g|=       0.14354
# At iterate    14  f =       163.83  |proj g|=      0.011747
# At iterate    15  f =       163.83  |proj g|=      0.010277
# At iterate    16  f =       163.83  |proj g|=      0.019233
# At iterate    17  f =       163.83  |proj g|=      0.050785
# At iterate    18  f =       163.83  |proj g|=       0.10017
# At iterate    19  f =       163.83  |proj g|=        0.1823
# At iterate    20  f =       163.83  |proj g|=       0.31771
# At iterate    21  f =       163.82  |proj g|=       0.54973
# At iterate    22  f =       163.82  |proj g|=        0.9832
# At iterate    23  f =        163.8  |proj g|=        2.0044
# At iterate    24  f =       163.76  |proj g|=        4.6844
# At iterate    25  f =       163.72  |proj g|=        4.0088
# At iterate    26  f =       163.59  |proj g|=        1.0196
# At iterate    27  f =       163.58  |proj g|=       0.31915
# At iterate    28  f =       163.58  |proj g|=      0.070415
# At iterate    29  f =       163.57  |proj g|=      0.071988
# At iterate    30  f =       163.57  |proj g|=       0.18734
# At iterate    31  f =       163.57  |proj g|=       0.33829
# At iterate    32  f =       163.56  |proj g|=       0.35632
# At iterate    33  f =       163.43  |proj g|=        0.5971
# At iterate    34  f =       163.42  |proj g|=       0.62902
# At iterate    35  f =       163.25  |proj g|=       0.56532
# At iterate    36  f =       163.12  |proj g|=      0.048737
# At iterate    37  f =       163.11  |proj g|=      0.055002
# At iterate    38  f =       163.11  |proj g|=      0.017139
# At iterate    39  f =       163.08  |proj g|=       0.81716
# At iterate    40  f =       162.83  |proj g|=        2.5001
# At iterate    41  f =        162.8  |proj g|=        2.6589
# At iterate    42  f =       162.27  |proj g|=        1.6056
# At iterate    43  f =       162.14  |proj g|=       0.36038
# At iterate    44  f =       161.73  |proj g|=       0.05274
# At iterate    45  f =       161.71  |proj g|=       0.13049
# At iterate    46  f =        161.7  |proj g|=      0.078268
# At iterate    47  f =        161.7  |proj g|=      0.046888
# At iterate    48  f =       161.69  |proj g|=     0.0017148
# At iterate    49  f =       161.69  |proj g|=    0.00026202
# At iterate    50  f =       161.69  |proj g|=    7.8337e-05
#
# iterations 50
# function evaluations 68
# segments explored during Cauchy searches 50
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 7.83366e-05
# final function value 161.694
#
# F = 161.694
# final  value 161.694092
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.94558 18.73695 18.72577 19.65322 17.35953
#   - best initial criterion value(s) :  -167.9979
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=          168  |proj g|=      0.12894
# At iterate     1  f =       167.99  |proj g|=       0.12886
# At iterate     2  f =       167.98  |proj g|=       0.18366
# At iterate     3  f =       167.94  |proj g|=      0.034199
# At iterate     4  f =       167.94  |proj g|=      0.032041
# At iterate     5  f =       167.93  |proj g|=      0.051815
# At iterate     6  f =       167.85  |proj g|=       0.34525
# At iterate     7  f =       167.82  |proj g|=       0.44985
# At iterate     8  f =       167.79  |proj g|=       0.11295
# At iterate     9  f =       167.77  |proj g|=       0.11805
# At iterate    10  f =       167.77  |proj g|=      0.033839
# At iterate    11  f =       167.77  |proj g|=       0.22396
# At iterate    12  f =       167.76  |proj g|=       0.41822
# At iterate    13  f =       167.75  |proj g|=        0.4284
# At iterate    14  f =       167.71  |proj g|=       0.43354
# At iterate    15  f =       167.63  |proj g|=       0.41394
# At iterate    16  f =       167.61  |proj g|=       0.39948
# At iterate    17  f =        167.6  |proj g|=       0.15316
# At iterate    18  f =        167.6  |proj g|=      0.010883
# At iterate    19  f =        167.6  |proj g|=      0.010898
# At iterate    20  f =        167.6  |proj g|=       0.01679
# At iterate    21  f =        167.6  |proj g|=      0.040072
# At iterate    22  f =        167.6  |proj g|=      0.069563
# At iterate    23  f =        167.6  |proj g|=       0.10291
# At iterate    24  f =        167.6  |proj g|=       0.11387
# At iterate    25  f =        167.6  |proj g|=      0.097737
# At iterate    26  f =       167.59  |proj g|=       0.13971
# At iterate    27  f =       167.59  |proj g|=       0.17297
# At iterate    28  f =       167.58  |proj g|=      0.070349
# At iterate    29  f =       167.58  |proj g|=       0.08835
# At iterate    30  f =       167.57  |proj g|=       0.10247
# At iterate    31  f =       167.57  |proj g|=      0.014927
# At iterate    32  f =       167.57  |proj g|=    0.00041049
# At iterate    33  f =       167.57  |proj g|=    8.5325e-07
#
# iterations 33
# function evaluations 38
# segments explored during Cauchy searches 34
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 3
# norm of the final projected gradient 8.53251e-07
# final function value 167.574
#
# F = 167.574
# final  value 167.574338
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.94558 18.73695 18.72577 19.65322 17.35953
#   - best initial criterion value(s) :  -169.3491
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       169.35  |proj g|=       8.5246
# At iterate     1  f =        168.9  |proj g|=       0.56641
# At iterate     2  f =       168.89  |proj g|=       0.39623
# At iterate     3  f =       168.89  |proj g|=         0.401
# At iterate     4  f =       168.87  |proj g|=       0.40817
# At iterate     5  f =       168.82  |proj g|=       0.40874
# At iterate     6  f =       168.71  |proj g|=       0.38261
# At iterate     7  f =        168.5  |proj g|=       0.30032
# At iterate     8  f =       168.18  |proj g|=       0.31588
# At iterate     9  f =       167.72  |proj g|=        1.2351
# At iterate    10  f =       167.59  |proj g|=       0.15982
# At iterate    11  f =       167.54  |proj g|=       0.23421
# At iterate    12  f =       167.48  |proj g|=      0.060713
# At iterate    13  f =       167.41  |proj g|=        0.2419
# At iterate    14  f =       167.41  |proj g|=      0.053754
# At iterate    15  f =       167.41  |proj g|=       0.23583
# At iterate    16  f =       167.41  |proj g|=       0.23483
# At iterate    17  f =       167.39  |proj g|=       0.36876
# At iterate    18  f =       167.36  |proj g|=       0.98448
# At iterate    19  f =       167.36  |proj g|=       0.50076
# At iterate    20  f =       167.35  |proj g|=      0.060058
# At iterate    21  f =       167.35  |proj g|=       0.12155
# At iterate    22  f =       167.35  |proj g|=       0.39005
# At iterate    23  f =       167.35  |proj g|=       0.21629
# At iterate    24  f =       167.35  |proj g|=      0.029896
# At iterate    25  f =       167.35  |proj g|=      0.032449
# At iterate    26  f =       167.34  |proj g|=       0.23113
# At iterate    27  f =       167.34  |proj g|=      0.061049
# At iterate    28  f =       167.34  |proj g|=       0.37011
# At iterate    29  f =       167.33  |proj g|=       0.56415
# At iterate    30  f =       167.31  |proj g|=       0.91665
# At iterate    31  f =       167.27  |proj g|=        1.1063
# At iterate    32  f =       167.27  |proj g|=         1.537
# At iterate    33  f =       167.25  |proj g|=       0.98628
# At iterate    34  f =       167.24  |proj g|=       0.11016
# At iterate    35  f =       167.24  |proj g|=     0.0076956
# At iterate    36  f =       167.24  |proj g|=       0.08102
# At iterate    37  f =       167.24  |proj g|=      0.046584
# At iterate    38  f =       167.24  |proj g|=     0.0056003
# At iterate    39  f =       167.24  |proj g|=    0.00021725
# At iterate    40  f =       167.24  |proj g|=    1.0427e-05
#
# iterations 40
# function evaluations 48
# segments explored during Cauchy searches 40
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 1.04271e-05
# final function value 167.237
#
# F = 167.237
# final  value 167.237288
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.94558 18.73695 18.72577 19.65322 17.35953
#   - best initial criterion value(s) :  -168.276
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       168.28  |proj g|=      0.30357
# At iterate     1  f =       168.16  |proj g|=       0.29815
# At iterate     2  f =       168.03  |proj g|=       0.21269
# At iterate     3  f =       167.81  |proj g|=      0.056399
# At iterate     4  f =       167.77  |proj g|=      0.046701
# At iterate     5  f =       167.76  |proj g|=      0.023957
# At iterate     6  f =       167.75  |proj g|=      0.027632
# At iterate     7  f =       167.75  |proj g|=       0.03941
# At iterate     8  f =       167.75  |proj g|=     0.0056544
# At iterate     9  f =       167.75  |proj g|=      0.005686
# At iterate    10  f =       167.75  |proj g|=       0.00858
# At iterate    11  f =       167.75  |proj g|=      0.012466
# At iterate    12  f =       167.74  |proj g|=      0.026363
# At iterate    13  f =       167.74  |proj g|=      0.032999
# At iterate    14  f =       167.74  |proj g|=       0.01963
# At iterate    15  f =       167.74  |proj g|=      0.016685
# At iterate    16  f =       167.73  |proj g|=      0.015556
# At iterate    17  f =       167.73  |proj g|=      0.010953
# At iterate    18  f =       167.73  |proj g|=     0.0059012
# At iterate    19  f =       167.73  |proj g|=     0.0012354
# At iterate    20  f =       167.73  |proj g|=    0.00035643
# At iterate    21  f =       167.73  |proj g|=    0.00071333
# At iterate    22  f =       167.73  |proj g|=    0.00028264
#
# iterations 22
# function evaluations 24
# segments explored during Cauchy searches 22
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.000282643
# final function value 167.731
#
# F = 167.731
# final  value 167.730742
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.24322 19.57545 19.80036 19.7163 19.00813
#   - best initial criterion value(s) :  -171.3311
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       171.33  |proj g|=      0.41367
# At iterate     1  f =       170.78  |proj g|=         2.118
# At iterate     2  f =       170.74  |proj g|=      0.076742
# At iterate     3  f =        170.7  |proj g|=        1.1233
# At iterate     4  f =       170.62  |proj g|=        2.3715
# At iterate     5  f =       170.54  |proj g|=        3.4007
# At iterate     6  f =       170.49  |proj g|=        2.7677
# At iterate     7  f =       170.41  |proj g|=       0.40075
# At iterate     8  f =        170.4  |proj g|=       0.16342
# At iterate     9  f =        170.4  |proj g|=       0.05945
# At iterate    10  f =        170.4  |proj g|=       0.14394
# At iterate    11  f =        170.4  |proj g|=       0.26063
# At iterate    12  f =       170.39  |proj g|=        0.3133
# At iterate    13  f =       170.38  |proj g|=       0.32639
# At iterate    14  f =       170.36  |proj g|=       0.34276
# At iterate    15  f =       170.33  |proj g|=       0.34885
# At iterate    16  f =       170.29  |proj g|=       0.35373
# At iterate    17  f =       170.17  |proj g|=       0.68115
# At iterate    18  f =       170.15  |proj g|=      0.068252
# At iterate    19  f =       170.14  |proj g|=      0.031625
# At iterate    20  f =       170.13  |proj g|=      0.024045
# At iterate    21  f =       170.13  |proj g|=      0.038483
# At iterate    22  f =       170.13  |proj g|=       0.07005
# At iterate    23  f =       170.12  |proj g|=      0.060952
# At iterate    24  f =       170.12  |proj g|=      0.031114
# At iterate    25  f =       170.11  |proj g|=      0.014599
# At iterate    26  f =       170.11  |proj g|=     0.0078455
# At iterate    27  f =       170.11  |proj g|=     0.0063593
# At iterate    28  f =       170.11  |proj g|=      0.018501
# At iterate    29  f =       170.11  |proj g|=      0.027157
# At iterate    30  f =       170.11  |proj g|=       0.12958
# At iterate    31  f =        170.1  |proj g|=      0.049252
# At iterate    32  f =        170.1  |proj g|=      0.016584
# At iterate    33  f =        170.1  |proj g|=     0.0039203
# At iterate    34  f =        170.1  |proj g|=     0.0051201
# At iterate    35  f =        170.1  |proj g|=      0.003101
# At iterate    36  f =        170.1  |proj g|=      0.013335
# At iterate    37  f =        170.1  |proj g|=     0.0016851
# At iterate    38  f =        170.1  |proj g|=    0.00015874
#
# iterations 38
# function evaluations 52
# segments explored during Cauchy searches 39
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.000158735
# final function value 170.099
#
# F = 170.099
# final  value 170.099294
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.24322 19.57545 19.80036 19.7163 19.00813
#   - best initial criterion value(s) :  -171.0744
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       171.07  |proj g|=     0.026641
# At iterate     1  f =       171.07  |proj g|=      0.026083
# At iterate     2  f =       171.06  |proj g|=       0.90792
# At iterate     3  f =       171.06  |proj g|=      0.023847
# At iterate     4  f =       171.06  |proj g|=      0.029038
# At iterate     5  f =       171.06  |proj g|=      0.050492
# At iterate     6  f =       171.06  |proj g|=       0.15118
# At iterate     7  f =       171.06  |proj g|=       0.27358
# At iterate     8  f =       171.06  |proj g|=       0.49792
# At iterate     9  f =       171.06  |proj g|=       0.84661
# At iterate    10  f =       171.06  |proj g|=        1.4305
# At iterate    11  f =       171.06  |proj g|=        2.4002
# At iterate    12  f =       171.06  |proj g|=        4.0485
# At iterate    13  f =       171.06  |proj g|=        6.9105
# At iterate    14  f =       171.04  |proj g|=        12.146
# At iterate    15  f =          171  |proj g|=         19.78
# At iterate    16  f =       170.98  |proj g|=        17.382
# At iterate    17  f =       170.92  |proj g|=         3.992
# At iterate    18  f =       170.92  |proj g|=       0.94556
# At iterate    19  f =       170.92  |proj g|=      0.066731
# At iterate    20  f =       170.92  |proj g|=      0.055838
# At iterate    21  f =       170.92  |proj g|=      0.056072
# At iterate    22  f =       170.92  |proj g|=      0.056453
# At iterate    23  f =       170.92  |proj g|=      0.057081
# At iterate    24  f =       170.92  |proj g|=       0.05813
# At iterate    25  f =       170.92  |proj g|=      0.059918
# At iterate    26  f =       170.92  |proj g|=      0.063073
# At iterate    27  f =       170.91  |proj g|=      0.068991
# At iterate    28  f =       170.91  |proj g|=      0.080005
# At iterate    29  f =       170.89  |proj g|=      0.078611
# At iterate    30  f =       170.87  |proj g|=      0.044107
# At iterate    31  f =       170.86  |proj g|=      0.042008
# At iterate    32  f =       170.85  |proj g|=      0.036301
# At iterate    33  f =       170.85  |proj g|=      0.035249
# At iterate    34  f =       170.85  |proj g|=      0.035205
# At iterate    35  f =       170.85  |proj g|=     0.0051755
# At iterate    36  f =       170.85  |proj g|=     0.0051757
#
# iterations 36
# function evaluations 47
# segments explored during Cauchy searches 37
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.00517568
# final function value 170.851
#
# F = 170.851
# final  value 170.851072
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  18.24322 19.57545 19.80036 19.7163 19.00813
#   - best initial criterion value(s) :  -170.5939
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       170.59  |proj g|=      0.32884
# At iterate     1  f =       170.58  |proj g|=      0.069749
# At iterate     2  f =       170.57  |proj g|=      0.095237
# At iterate     3  f =       170.55  |proj g|=       0.20751
# At iterate     4  f =       170.35  |proj g|=        0.9861
# At iterate     5  f =       170.34  |proj g|=        1.5735
# At iterate     6  f =       170.26  |proj g|=       0.84806
# At iterate     7  f =       170.25  |proj g|=      0.028165
# At iterate     8  f =       170.25  |proj g|=      0.044917
# At iterate     9  f =        170.2  |proj g|=      0.028789
# At iterate    10  f =       170.15  |proj g|=       0.94057
# At iterate    11  f =       170.14  |proj g|=       0.13873
# At iterate    12  f =       170.14  |proj g|=      0.010764
# At iterate    13  f =       170.14  |proj g|=      0.010139
# At iterate    14  f =       170.14  |proj g|=      0.013765
# At iterate    15  f =       170.14  |proj g|=      0.020096
# At iterate    16  f =       170.14  |proj g|=      0.041587
# At iterate    17  f =       170.13  |proj g|=      0.082491
# At iterate    18  f =       170.13  |proj g|=       0.10533
# At iterate    19  f =       170.13  |proj g|=         0.229
# At iterate    20  f =       170.13  |proj g|=       0.23189
# At iterate    21  f =       170.11  |proj g|=      0.052561
# At iterate    22  f =       170.11  |proj g|=      0.011881
# At iterate    23  f =       170.11  |proj g|=      0.018707
# At iterate    24  f =       170.11  |proj g|=      0.011873
# At iterate    25  f =        170.1  |proj g|=      0.031768
# At iterate    26  f =        170.1  |proj g|=      0.011746
# At iterate    27  f =        170.1  |proj g|=      0.011727
# At iterate    28  f =        170.1  |proj g|=      0.039193
# At iterate    29  f =        170.1  |proj g|=      0.016645
# At iterate    30  f =        170.1  |proj g|=      0.048593
# At iterate    31  f =        170.1  |proj g|=      0.013869
# At iterate    32  f =        170.1  |proj g|=     0.0028993
# At iterate    33  f =        170.1  |proj g|=      0.001671
#
# iterations 33
# function evaluations 46
# segments explored during Cauchy searches 33
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.00167097
# final function value 170.099
#
# F = 170.099
# final  value 170.099294
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.05949 18.53836 18.28215 19.7637 18.12434
#   - best initial criterion value(s) :  -167.0935
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       167.09  |proj g|=      0.45169
# At iterate     1  f =       166.87  |proj g|=       0.44565
# At iterate     2  f =       166.75  |proj g|=        0.4291
# At iterate     3  f =       166.53  |proj g|=       0.33643
# At iterate     4  f =        166.5  |proj g|=        1.1424
# At iterate     5  f =        166.1  |proj g|=       0.39495
# At iterate     6  f =       165.43  |proj g|=       0.82827
# At iterate     7  f =       164.94  |proj g|=       0.62072
# At iterate     8  f =       164.52  |proj g|=       0.44574
# At iterate     9  f =       164.07  |proj g|=       0.31131
# At iterate    10  f =       163.43  |proj g|=       0.53986
# At iterate    11  f =       163.35  |proj g|=      0.044527
# At iterate    12  f =       163.35  |proj g|=      0.031125
# At iterate    13  f =       163.35  |proj g|=      0.031186
# At iterate    14  f =       163.35  |proj g|=      0.093483
# At iterate    15  f =       163.35  |proj g|=       0.18145
# At iterate    16  f =       163.35  |proj g|=       0.31667
# At iterate    17  f =       163.34  |proj g|=       0.46985
# At iterate    18  f =       163.34  |proj g|=       0.54504
# At iterate    19  f =       163.32  |proj g|=       0.14727
# At iterate    20  f =       163.32  |proj g|=      0.016727
# At iterate    21  f =       163.32  |proj g|=       0.01694
# At iterate    22  f =       163.32  |proj g|=      0.017699
# At iterate    23  f =       163.32  |proj g|=       0.06805
# At iterate    24  f =       163.32  |proj g|=      0.098696
# At iterate    25  f =       163.32  |proj g|=        0.1572
# At iterate    26  f =       163.32  |proj g|=      0.010238
# At iterate    27  f =       163.31  |proj g|=      0.054104
# At iterate    28  f =       163.31  |proj g|=      0.032393
# At iterate    29  f =       163.31  |proj g|=      0.018732
# At iterate    30  f =       163.31  |proj g|=    0.00069918
# At iterate    31  f =       163.31  |proj g|=        0.0007
#
# iterations 31
# function evaluations 38
# segments explored during Cauchy searches 33
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.000700002
# final function value 163.314
#
# F = 163.314
# final  value 163.314069
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.05949 18.53836 18.28215 19.7637 18.12434
#   - best initial criterion value(s) :  -165.7387
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       165.74  |proj g|=       13.001
# At iterate     1  f =       165.55  |proj g|=       0.79847
# At iterate     2  f =        164.1  |proj g|=        0.5344
# At iterate     3  f =       163.93  |proj g|=        0.3372
# At iterate     4  f =       163.93  |proj g|=        0.1032
# At iterate     5  f =       163.87  |proj g|=      0.094769
# At iterate     6  f =       163.73  |proj g|=       0.20486
# At iterate     7  f =       163.07  |proj g|=       0.46567
# At iterate     8  f =       162.98  |proj g|=      0.041547
# At iterate     9  f =       162.96  |proj g|=       0.11654
# At iterate    10  f =       162.96  |proj g|=       0.13382
# At iterate    11  f =       162.95  |proj g|=      0.059518
# At iterate    12  f =       162.95  |proj g|=      0.044223
# At iterate    13  f =       162.95  |proj g|=      0.029444
# At iterate    14  f =       162.94  |proj g|=      0.059027
# At iterate    15  f =       162.93  |proj g|=       0.11684
# At iterate    16  f =       162.92  |proj g|=       0.49724
# At iterate    17  f =       162.91  |proj g|=      0.068418
# At iterate    18  f =       162.89  |proj g|=       0.25093
# At iterate    19  f =       162.88  |proj g|=      0.072368
# At iterate    20  f =       162.88  |proj g|=      0.085346
# At iterate    21  f =       162.87  |proj g|=      0.083607
# At iterate    22  f =       162.87  |proj g|=     0.0070095
# At iterate    23  f =       162.87  |proj g|=      0.019594
# At iterate    24  f =       162.87  |proj g|=     0.0027708
# At iterate    25  f =       162.87  |proj g|=    7.8428e-05
# At iterate    26  f =       162.87  |proj g|=    5.2172e-05
#
# iterations 26
# function evaluations 36
# segments explored during Cauchy searches 26
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.21721e-05
# final function value 162.873
#
# F = 162.873
# final  value 162.873351
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.05949 18.53836 18.28215 19.7637 18.12434
#   - best initial criterion value(s) :  -167.5625
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       167.56  |proj g|=      0.24816
# At iterate     1  f =       167.49  |proj g|=       0.20972
# At iterate     2  f =       167.29  |proj g|=       0.22452
# At iterate     3  f =        167.2  |proj g|=      0.069528
# At iterate     4  f =       167.16  |proj g|=      0.081454
# At iterate     5  f =       167.07  |proj g|=       0.08134
# At iterate     6  f =       167.07  |proj g|=       0.12506
# At iterate     7  f =       167.02  |proj g|=      0.087451
# At iterate     8  f =       166.93  |proj g|=      0.092858
# ...
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  17.57029 18.17861 18.32407 19.50629 17.02036
#   - best initial criterion value(s) :  -169.4029
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        169.4  |proj g|=      0.56658
# At iterate     1  f =       168.69  |proj g|=        2.7123
# At iterate     2  f =       168.62  |proj g|=       0.73191
# At iterate     3  f =       168.55  |proj g|=       0.64295
# At iterate     4  f =       168.14  |proj g|=       0.66474
# At iterate     5  f =       168.04  |proj g|=       0.15872
# At iterate     6  f =       167.99  |proj g|=       0.16017
# At iterate     7  f =       167.89  |proj g|=       0.21408
# At iterate     8  f =       167.87  |proj g|=       0.31937
# At iterate     9  f =       167.04  |proj g|=       0.31708
# At iterate    10  f =       166.82  |proj g|=       0.55064
# At iterate    11  f =       166.81  |proj g|=       0.31587
# At iterate    12  f =       166.81  |proj g|=      0.045986
# At iterate    13  f =        166.8  |proj g|=       0.09232
# At iterate    14  f =        166.8  |proj g|=       0.30303
# At iterate    15  f =       166.78  |proj g|=       0.30897
# At iterate    16  f =       166.74  |proj g|=       0.31415
# At iterate    17  f =        166.7  |proj g|=       0.30797
# At iterate    18  f =       166.67  |proj g|=       0.30369
# At iterate    19  f =       166.66  |proj g|=       0.46837
# At iterate    20  f =       166.66  |proj g|=      0.054288
# At iterate    21  f =       166.66  |proj g|=     0.0095613
# At iterate    22  f =       166.66  |proj g|=      0.011141
# At iterate    23  f =       166.66  |proj g|=       0.06303
# At iterate    24  f =       166.66  |proj g|=       0.13863
# At iterate    25  f =       166.66  |proj g|=       0.25961
# At iterate    26  f =       166.66  |proj g|=       0.42897
# At iterate    27  f =       166.66  |proj g|=       0.65136
# At iterate    28  f =       166.65  |proj g|=       0.81807
# At iterate    29  f =       166.64  |proj g|=       0.63625
# At iterate    30  f =       166.64  |proj g|=       0.12483
# At iterate    31  f =       166.64  |proj g|=       0.13994
# At iterate    32  f =       166.63  |proj g|=        0.2181
# At iterate    33  f =       166.63  |proj g|=        0.2891
# At iterate    34  f =       166.63  |proj g|=       0.28725
# At iterate    35  f =       166.63  |proj g|=      0.055528
# At iterate    36  f =       166.63  |proj g|=     0.0062484
# At iterate    37  f =       166.63  |proj g|=    0.00015864
# At iterate    38  f =       166.63  |proj g|=    6.1564e-05
#
# iterations 38
# function evaluations 46
# segments explored during Cauchy searches 39
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 3
# norm of the final projected gradient 6.15636e-05
# final function value 166.628
#
# F = 166.628
# final  value 166.627626
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  17.57029 18.17861 18.32407 19.50629 17.02036
#   - best initial criterion value(s) :  -168.9602
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       168.96  |proj g|=      0.15544
# At iterate     1  f =       168.95  |proj g|=       0.15543
# At iterate     2  f =       168.94  |proj g|=       0.44217
# At iterate     3  f =       168.94  |proj g|=       0.30442
# At iterate     4  f =       168.94  |proj g|=       0.15539
# At iterate     5  f =       168.93  |proj g|=       0.15503
# At iterate     6  f =       168.92  |proj g|=       0.15421
# At iterate     7  f =       168.87  |proj g|=       0.15246
# At iterate     8  f =       168.76  |proj g|=       0.14543
# At iterate     9  f =       168.64  |proj g|=       0.13385
# At iterate    10  f =       168.53  |proj g|=       0.12422
# At iterate    11  f =       168.49  |proj g|=       0.87597
# At iterate    12  f =       168.48  |proj g|=      0.094446
# At iterate    13  f =       168.48  |proj g|=      0.022567
# At iterate    14  f =       168.48  |proj g|=      0.022574
# At iterate    15  f =       168.48  |proj g|=      0.022579
# At iterate    16  f =       168.48  |proj g|=      0.059863
# At iterate    17  f =       168.48  |proj g|=       0.12751
# At iterate    18  f =       168.48  |proj g|=        0.3458
# At iterate    19  f =       168.47  |proj g|=      0.095725
# At iterate    20  f =       168.47  |proj g|=       0.29618
# At iterate    21  f =       168.45  |proj g|=        1.2883
# At iterate    22  f =       168.41  |proj g|=        1.9094
# At iterate    23  f =        168.4  |proj g|=        1.2602
# At iterate    24  f =        168.4  |proj g|=       0.48278
# At iterate    25  f =       168.39  |proj g|=      0.018291
# At iterate    26  f =       168.39  |proj g|=     0.0081742
# At iterate    27  f =       168.39  |proj g|=      0.044158
# At iterate    28  f =       168.39  |proj g|=      0.098375
# At iterate    29  f =       168.39  |proj g|=      0.099465
# At iterate    30  f =       168.39  |proj g|=       0.10115
# At iterate    31  f =       168.39  |proj g|=       0.10464
# At iterate    32  f =       168.36  |proj g|=       0.12609
# ys=-1.979e-02  -gs= 2.323e-02, BFGS update SKIPPED
# At iterate    33  f =       168.36  |proj g|=       0.12342
# At iterate    34  f =       168.34  |proj g|=       0.60797
# At iterate    35  f =       168.34  |proj g|=      0.045234
# At iterate    36  f =       168.34  |proj g|=      0.033625
# At iterate    37  f =       168.34  |proj g|=      0.064905
# At iterate    38  f =       168.34  |proj g|=       0.14242
# At iterate    39  f =       168.34  |proj g|=       0.21315
# At iterate    40  f =       168.34  |proj g|=       0.24075
# At iterate    41  f =       168.34  |proj g|=       0.15302
# At iterate    42  f =       168.34  |proj g|=      0.017335
# At iterate    43  f =       168.34  |proj g|=      0.090876
# At iterate    44  f =       168.34  |proj g|=       0.10865
# At iterate    45  f =       168.34  |proj g|=       0.11005
# At iterate    46  f =       168.33  |proj g|=       0.11279
# At iterate    47  f =       168.33  |proj g|=       0.11886
# At iterate    48  f =       168.21  |proj g|=          0.17
# ys=-1.385e-03  -gs= 5.111e-02, BFGS update SKIPPED
# At iterate    49  f =       168.21  |proj g|=       0.17221
# At iterate    50  f =       168.21  |proj g|=       0.17149
# At iterate    51  f =        168.2  |proj g|=       0.32429
# At iterate    52  f =        168.2  |proj g|=       0.38991
# At iterate    53  f =        168.2  |proj g|=       0.54023
# At iterate    54  f =       168.14  |proj g|=        2.3206
# At iterate    55  f =       168.13  |proj g|=        2.8159
# At iterate    56  f =       168.06  |proj g|=        2.9394
# At iterate    57  f =       167.76  |proj g|=        1.9189
# At iterate    58  f =       167.66  |proj g|=        1.7436
# At iterate    59  f =       167.28  |proj g|=       0.22431
# At iterate    60  f =       167.26  |proj g|=       0.33587
# At iterate    61  f =       167.24  |proj g|=      0.046501
# At iterate    62  f =       167.24  |proj g|=     0.0092275
# At iterate    63  f =       167.24  |proj g|=     0.0018214
# At iterate    64  f =       167.24  |proj g|=     0.0018318
# At iterate    65  f =       167.24  |proj g|=      0.012634
# At iterate    66  f =       167.24  |proj g|=      0.028122
# At iterate    67  f =       167.24  |proj g|=      0.055749
# At iterate    68  f =       167.22  |proj g|=       0.14259
# ys=-2.313e-03  -gs= 1.249e-02, BFGS update SKIPPED
# At iterate    69  f =       167.21  |proj g|=       0.16343
# At iterate    70  f =        167.2  |proj g|=      0.044193
# At iterate    71  f =        167.2  |proj g|=       0.10774
# At iterate    72  f =       167.18  |proj g|=        0.1907
# At iterate    73  f =       167.17  |proj g|=       0.21757
# At iterate    74  f =       167.14  |proj g|=       0.18242
# At iterate    75  f =       167.08  |proj g|=       0.19052
# At iterate    76  f =       167.05  |proj g|=        0.1222
# At iterate    77  f =       167.02  |proj g|=      0.060118
# At iterate    78  f =       167.01  |proj g|=      0.018654
# At iterate    79  f =       167.01  |proj g|=     0.0030352
# At iterate    80  f =       167.01  |proj g|=    0.00024051
# At iterate    81  f =       167.01  |proj g|=    2.1513e-05
#
# iterations 81
# function evaluations 119
# segments explored during Cauchy searches 82
# BFGS updates skipped 3
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.15133e-05
# final function value 167.008
#
# F = 167.008
# final  value 167.007693
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.51693 19.50993 19.51583 18.88543 19.1993
#   - best initial criterion value(s) :  -171.6887
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       171.69  |proj g|=       6.6799
# At iterate     1  f =       170.61  |proj g|=       0.74643
# At iterate     2  f =       170.55  |proj g|=       0.57477
# At iterate     3  f =       170.45  |proj g|=        1.3819
# At iterate     4  f =       170.35  |proj g|=       0.37177
# At iterate     5  f =       170.05  |proj g|=       0.27064
# At iterate     6  f =       169.68  |proj g|=       0.46165
# At iterate     7  f =        169.5  |proj g|=       0.19911
# At iterate     8  f =       169.43  |proj g|=      0.073044
# At iterate     9  f =       169.41  |proj g|=      0.094716
# At iterate    10  f =       169.41  |proj g|=       0.14194
# At iterate    11  f =        169.4  |proj g|=      0.079491
# At iterate    12  f =       169.39  |proj g|=      0.021388
# At iterate    13  f =       169.39  |proj g|=      0.019945
# At iterate    14  f =       169.38  |proj g|=      0.018457
# At iterate    15  f =       169.37  |proj g|=      0.029939
# At iterate    16  f =       169.37  |proj g|=       0.09805
# At iterate    17  f =       169.37  |proj g|=      0.029873
# At iterate    18  f =       169.37  |proj g|=      0.022182
# At iterate    19  f =       169.37  |proj g|=     0.0075064
# At iterate    20  f =       169.37  |proj g|=     0.0036183
# At iterate    21  f =       169.37  |proj g|=     0.0059373
# At iterate    22  f =       169.36  |proj g|=     0.0030286
# At iterate    23  f =       169.36  |proj g|=     0.0024114
# At iterate    24  f =       169.36  |proj g|=    3.6479e-05
# At iterate    25  f =       169.36  |proj g|=    2.4998e-06
#
# iterations 25
# function evaluations 32
# segments explored during Cauchy searches 25
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 2.49982e-06
# final function value 169.365
#
# F = 169.365
# final  value 169.364944
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.51693 19.50993 19.51583 18.88543 19.1993
#   - best initial criterion value(s) :  -172.6164
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       172.62  |proj g|=       1.0202
# At iterate     1  f =       172.31  |proj g|=        1.2604
# At iterate     2  f =       171.04  |proj g|=         1.564
# At iterate     3  f =       170.95  |proj g|=       0.77482
# At iterate     4  f =       170.85  |proj g|=       0.14309
# At iterate     5  f =       170.84  |proj g|=       0.13714
# At iterate     6  f =       170.81  |proj g|=       0.35504
# At iterate     7  f =       170.75  |proj g|=       0.70729
# At iterate     8  f =       170.63  |proj g|=       0.83161
# At iterate     9  f =       170.46  |proj g|=       0.87338
# At iterate    10  f =       170.37  |proj g|=       0.46387
# At iterate    11  f =       170.25  |proj g|=       0.32667
# At iterate    12  f =       170.04  |proj g|=        0.1521
# At iterate    13  f =       169.42  |proj g|=      0.094885
# At iterate    14  f =       169.41  |proj g|=       0.12846
# At iterate    15  f =       169.37  |proj g|=       0.32408
# At iterate    16  f =       169.34  |proj g|=      0.091698
# At iterate    17  f =       169.33  |proj g|=      0.095953
# At iterate    18  f =       169.17  |proj g|=       0.48539
# At iterate    19  f =       169.07  |proj g|=       0.21739
# At iterate    20  f =       168.99  |proj g|=      0.075283
# At iterate    21  f =       168.98  |proj g|=       0.22129
# At iterate    22  f =       168.97  |proj g|=      0.025666
# At iterate    23  f =       168.97  |proj g|=     0.0034622
# At iterate    24  f =       168.97  |proj g|=    0.00087707
# At iterate    25  f =       168.97  |proj g|=    0.00060605
# At iterate    26  f =       168.97  |proj g|=    0.00023621
#
# iterations 26
# function evaluations 33
# segments explored during Cauchy searches 26
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.000236207
# final function value 168.971
#
# F = 168.971
# final  value 168.971123
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.51693 19.50993 19.51583 18.88543 19.1993
#   - best initial criterion value(s) :  -171.3509
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       171.35  |proj g|=       2.6073
# At iterate     1  f =       171.33  |proj g|=       0.70384
# At iterate     2  f =       170.96  |proj g|=       0.39608
# At iterate     3  f =       170.89  |proj g|=       0.54346
# At iterate     4  f =       170.81  |proj g|=       0.11971
# At iterate     5  f =        170.5  |proj g|=       0.47301
# At iterate     6  f =       170.49  |proj g|=       0.48593
# At iterate     7  f =       170.28  |proj g|=        0.2828
# At iterate     8  f =       170.03  |proj g|=       0.14748
# At iterate     9  f =       169.85  |proj g|=       0.18147
# At iterate    10  f =       169.72  |proj g|=       0.34233
# At iterate    11  f =        169.7  |proj g|=       0.63974
# At iterate    12  f =       169.67  |proj g|=      0.094838
# At iterate    13  f =       169.65  |proj g|=      0.097358
# At iterate    14  f =       169.51  |proj g|=        0.1485
# At iterate    15  f =       169.44  |proj g|=      0.073612
# At iterate    16  f =       169.39  |proj g|=       0.03312
# At iterate    17  f =       169.38  |proj g|=      0.023137
# At iterate    18  f =       169.38  |proj g|=      0.031352
# At iterate    19  f =       169.38  |proj g|=      0.021529
# At iterate    20  f =       169.38  |proj g|=      0.021014
# At iterate    21  f =       169.37  |proj g|=      0.030958
# At iterate    22  f =       169.37  |proj g|=      0.024049
# At iterate    23  f =       169.37  |proj g|=     0.0059391
# At iterate    24  f =       169.37  |proj g|=     0.0058014
# At iterate    25  f =       169.37  |proj g|=     0.0058747
# At iterate    26  f =       169.36  |proj g|=     0.0048062
# At iterate    27  f =       169.36  |proj g|=    4.9137e-05
# At iterate    28  f =       169.36  |proj g|=    3.2972e-05
#
# iterations 28
# function evaluations 42
# segments explored during Cauchy searches 28
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.29724e-05
# final function value 169.365
#
# F = 169.365
# final  value 169.364944
# converged

# %%
bla_5 = do.call(rbind, out_5)

p = ggplot(data = bla_5, aes(x = misspec, y = neg_loglik, colour = type)) + geom_boxplot() #+ ylim(c(0, 50))
p
# Out:
# plot without title

# %%
# Create a Table 
bla_5_s = setDT(bla_5)[, .(mean(neg_loglik), sd(neg_loglik)), by = c("misspec", "type", "dimension")]

bla_5_s$variant = paste0(bla_5_s$type, "_", bla_5_s$misspec)
bla_5_s$value = paste0(round(bla_5_s$V1, 2), " (", round(bla_5_s$V2, 2), ")")

reshape2::dcast(bla_5_s, formula = dimension ~ variant, value.var = "value")

# %%
bla = do.call(rbind, out)

p = ggplot(data = bla, aes(x = type, y = neg_loglik, colour = misspec)) + geom_boxplot() #+ ylim(c(0, 50))
p
# Out:
# plot without title

# %%
out = replicate(n = 10, simulate_kernel(dimension = 10, true_kernel = "matern3_2", wrong_kernel = "matern5_2", n = 50, objective = obj), simplify = FALSE)
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.50605 19.70826
#   - best initial criterion value(s) :  -199.1767
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       199.18  |proj g|=      0.59707
# At iterate     1  f =       198.62  |proj g|=       0.52747
# At iterate     2  f =       193.41  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 193.415
#
# F = 193.415
# final  value 193.414848
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.50605 19.70826
#   - best initial criterion value(s) :  -165.0814
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       165.08  |proj g|=       0.8601
# At iterate     1  f =       164.41  |proj g|=       0.58549
# At iterate     2  f =       163.81  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 163.806
#
# F = 163.806
# final  value 163.806360
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.50605 19.70826
#   - best initial criterion value(s) :  -194.241
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       194.24  |proj g|=      0.30852
# At iterate     1  f =       194.06  |proj g|=       0.30037
# At iterate     2  f =       193.41  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 193.415
#
# F = 193.415
# final  value 193.414848
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.86302 18.58789
#   - best initial criterion value(s) :  -188.7475
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       188.75  |proj g|=       1.2826
# At iterate     1  f =       187.26  |proj g|=       0.87438
# At iterate     2  f =       185.99  |proj g|=       0.17965
# At iterate     3  f =       185.94  |proj g|=       0.12075
# At iterate     4  f =        185.9  |proj g|=     0.0094882
# At iterate     5  f =        185.9  |proj g|=    0.00056397
# At iterate     6  f =        185.9  |proj g|=     2.883e-06
# At iterate     7  f =        185.9  |proj g|=    8.7877e-10
#
# iterations 7
# function evaluations 8
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 8.78772e-10
# final function value 185.896
#
# F = 185.896
# final  value 185.895649
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.86302 18.58789
#   - best initial criterion value(s) :  -163.9876
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       163.99  |proj g|=       1.0046
# At iterate     1  f =       162.52  |proj g|=       0.85217
# At iterate     2  f =       156.94  |proj g|=        0.4861
# At iterate     3  f =       156.71  |proj g|=             0
#
# iterations 3
# function evaluations 4
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 156.71
#
# F = 156.71
# final  value 156.710033
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.86302 18.58789
#   - best initial criterion value(s) :  -188.7804
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       188.78  |proj g|=      0.54426
# At iterate     1  f =       188.37  |proj g|=       0.46699
# At iterate     2  f =       185.97  |proj g|=       0.16013
# At iterate     3  f =        185.9  |proj g|=     0.0013612
# Nonpositive definiteness in Cholesky factorization in formk;
#    refresh the lbfgs memory and restart the iteration.
# At iterate     4  f =        185.9  |proj g|=     0.0011622
# At iterate     5  f =        185.9  |proj g|=    8.6094e-07
# At iterate     6  f =        185.9  |proj g|=    5.4057e-10
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 9
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.4057e-10
# final function value 185.896
#
# F = 185.896
# final  value 185.895649
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.54285 19.44609
#   - best initial criterion value(s) :  -192.7
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        192.7  |proj g|=       1.1711
# At iterate     1  f =       191.45  |proj g|=       0.84848
# At iterate     2  f =       189.61  |proj g|=       0.26753
# At iterate     3  f =       189.34  |proj g|=       0.18981
# At iterate     4  f =       189.26  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 189.256
#
# F = 189.256
# final  value 189.256408
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.54285 19.44609
#   - best initial criterion value(s) :  -162.5101
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       162.51  |proj g|=       1.8704
# At iterate     1  f =       159.97  |proj g|=       0.76826
# At iterate     2  f =       158.91  |proj g|=       0.35718
# At iterate     3  f =       158.53  |proj g|=             0
#
# iterations 3
# function evaluations 4
# segments explored during Cauchy searches 4
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 158.527
#
# F = 158.527
# final  value 158.526835
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.54285 19.44609
#   - best initial criterion value(s) :  -190.2498
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       190.25  |proj g|=      0.58044
# At iterate     1  f =       189.94  |proj g|=       0.49015
# At iterate     2  f =       189.28  |proj g|=       0.13988
# At iterate     3  f =       189.26  |proj g|=             0
#
# iterations 3
# function evaluations 4
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 189.256
#
# F = 189.256
# final  value 189.256408
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.26555 19.14493
#   - best initial criterion value(s) :  -189.976
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       189.98  |proj g|=      0.50979
# At iterate     1  f =       189.67  |proj g|=       0.44167
# At iterate     2  f =       188.88  |proj g|=       0.10834
# At iterate     3  f =       188.85  |proj g|=             0
#
# iterations 3
# function evaluations 4
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 188.855
#
# F = 188.855
# final  value 188.854995
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.26555 19.14493
#   - best initial criterion value(s) :  -164.3937
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       164.39  |proj g|=      0.86573
# At iterate     1  f =       163.56  |proj g|=       0.61465
# At iterate     2  f =        162.3  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 162.3
#
# F = 162.3
# final  value 162.299521
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.26555 19.14493
#   - best initial criterion value(s) :  -191.8895
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       191.89  |proj g|=       1.3498
# At iterate     1  f =       190.25  |proj g|=       0.93034
# At iterate     2  f =       188.91  |proj g|=       0.14491
# At iterate     3  f =       188.87  |proj g|=      0.098241
# At iterate     4  f =       188.85  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 188.855
#
# F = 188.855
# final  value 188.854995
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.77866 18.51131
#   - best initial criterion value(s) :  -192.6766
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       192.68  |proj g|=        1.063
# At iterate     1  f =       191.74  |proj g|=       0.71513
# At iterate     2  f =       190.65  |proj g|=       0.19985
# At iterate     3  f =       190.54  |proj g|=      0.052528
# At iterate     4  f =       190.53  |proj g|=      0.005381
# At iterate     5  f =       190.53  |proj g|=    0.00016777
# At iterate     6  f =       190.53  |proj g|=    5.5974e-07
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.59736e-07
# final function value 190.53
#
# F = 190.53
# final  value 190.530272
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.77866 18.51131
#   - best initial criterion value(s) :  -162.2325
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       162.23  |proj g|=      0.75332
# At iterate     1  f =       161.68  |proj g|=       0.46465
# At iterate     2  f =       161.43  |proj g|=      0.084372
# At iterate     3  f =       161.42  |proj g|=     0.0082218
# At iterate     4  f =       161.42  |proj g|=    0.00017356
# Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate     5  f =       161.42  |proj g|=    0.00010996
#
# iterations 5
# function evaluations 26
# segments explored during Cauchy searches 7
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.00010996
# final function value 161.422
#
# F = 161.422
# final  value 161.421614
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.77866 18.51131
#   - best initial criterion value(s) :  -193.865
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       193.87  |proj g|=       1.3795
# At iterate     1  f =          192  |proj g|=        1.0188
# At iterate     2  f =       190.53  |proj g|=       0.01631
# At iterate     3  f =       190.53  |proj g|=     0.0092004
# At iterate     4  f =       190.53  |proj g|=    9.1476e-05
# At iterate     5  f =       190.53  |proj g|=    5.2016e-07
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.20163e-07
# final function value 190.53
#
# F = 190.53
# final  value 190.530272
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.6513 17.91548
#   - best initial criterion value(s) :  -186.9551
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       186.96  |proj g|=      0.76523
# At iterate     1  f =       186.43  |proj g|=        0.6022
# At iterate     2  f =       185.82  |proj g|=       0.15168
# At iterate     3  f =       185.78  |proj g|=      0.089296
# At iterate     4  f =       185.76  |proj g|=     0.0070845
# At iterate     5  f =       185.76  |proj g|=    0.00036981
# At iterate     6  f =       185.76  |proj g|=    1.6488e-06
# Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# Line search cannot locate an adequate point after 20 function
# and gradient evaluations
# final  value 185.755883
# stopped after 6 iterations
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.6513 17.91548
#   - best initial criterion value(s) :  -169.0026
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=          169  |proj g|=       3.4766
# At iterate     1  f =       163.13  |proj g|=        1.5596
# At iterate     2  f =       161.76  |proj g|=       0.99444
# At iterate     3  f =       157.83  |proj g|=       0.10186
# At iterate     4  f =       157.82  |proj g|=      0.054036
# At iterate     5  f =       157.82  |proj g|=     0.0012955
# At iterate     6  f =       157.82  |proj g|=    1.7074e-05
# At iterate     7  f =       157.82  |proj g|=    9.4868e-08
# At iterate     8  f =       157.82  |proj g|=    9.4868e-08
#
# iterations 8
# function evaluations 20
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 9.48676e-08
# final function value 157.819
#
# F = 157.819
# l(0) > u(0).  No feasible solutionfinal  value 157.819451
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.6513 17.91548
#   - best initial criterion value(s) :  -185.947
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       185.95  |proj g|=      0.29511
# At iterate     1  f =       185.76  |proj g|=     0.0078858
# At iterate     2  f =       185.76  |proj g|=     0.0049186
# At iterate     3  f =       185.76  |proj g|=    2.4297e-05
# At iterate     4  f =       185.76  |proj g|=    7.5349e-08
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 7.53491e-08
# final function value 185.756
#
# F = 185.756
# final  value 185.755883
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.6309 18.47716
#   - best initial criterion value(s) :  -190.3646
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       190.36  |proj g|=      0.13821
# At iterate     1  f =       190.31  |proj g|=       0.12312
# At iterate     2  f =       190.27  |proj g|=      0.013699
# At iterate     3  f =       190.27  |proj g|=    0.00084896
# At iterate     4  f =       190.27  |proj g|=    6.3966e-06
# At iterate     5  f =       190.27  |proj g|=    3.0075e-09
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.00749e-09
# final function value 190.266
#
# F = 190.266
# final  value 190.265990
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.6309 18.47716
#   - best initial criterion value(s) :  -170.0108
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       170.01  |proj g|=        1.279
# At iterate     1  f =       168.38  |proj g|=       0.95059
# At iterate     2  f =       163.15  |proj g|=       0.49168
# At iterate     3  f =       162.88  |proj g|=      0.093056
# At iterate     4  f =       162.87  |proj g|=     0.0094288
# At iterate     5  f =       162.87  |proj g|=    0.00021362
# At iterate     6  f =       162.87  |proj g|=     5.126e-07
#
# iterations 6
# function evaluations 7
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.12598e-07
# final function value 162.865
#
# F = 162.865
# final  value 162.865142
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.6309 18.47716
#   - best initial criterion value(s) :  -190.6817
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       190.68  |proj g|=      0.41405
# At iterate     1  f =       190.52  |proj g|=       0.32245
# At iterate     2  f =       190.27  |proj g|=      0.050184
# At iterate     3  f =       190.27  |proj g|=     0.0070107
# At iterate     4  f =       190.27  |proj g|=    0.00018742
# At iterate     5  f =       190.27  |proj g|=    7.2678e-07
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 7.2678e-07
# final function value 190.266
#
# F = 190.266
# final  value 190.265990
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.18691 19.53122
#   - best initial criterion value(s) :  -185.8452
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       185.85  |proj g|=      0.76225
# At iterate     1  f =       185.33  |proj g|=      0.070923
# At iterate     2  f =       185.28  |proj g|=       0.05103
# At iterate     3  f =       185.27  |proj g|=     0.0051486
# At iterate     4  f =       185.27  |proj g|=    0.00013272
# At iterate     5  f =       185.27  |proj g|=    3.5851e-07
#
# iterations 5
# function evaluations 6
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.58505e-07
# final function value 185.271
#
# F = 185.271
# final  value 185.270987
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.18691 19.53122
#   - best initial criterion value(s) :  -157.1887
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       157.19  |proj g|=      0.60273
# At iterate     1  f =       156.55  |proj g|=       0.51068
# At iterate     2  f =       156.29  |proj g|=       0.16635
# At iterate     3  f =       156.25  |proj g|=      0.018504
# At iterate     4  f =       156.25  |proj g|=    0.00082342
# Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# Line search cannot locate an adequate point after 20 function
# and gradient evaluations
# final  value 156.251505
# stopped after 4 iterations
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.18691 19.53122
#   - best initial criterion value(s) :  -185.4994
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        185.5  |proj g|=      0.26233
# At iterate     1  f =       185.34  |proj g|=        0.1616
# At iterate     2  f =       185.27  |proj g|=     0.0030045
# At iterate     3  f =       185.27  |proj g|=    0.00022756
# At iterate     4  f =       185.27  |proj g|=    3.5925e-07
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.59249e-07
# final function value 185.271
#
# F = 185.271
# final  value 185.270987
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.35031 18.27895
#   - best initial criterion value(s) :  -181.2441
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       181.24  |proj g|=      0.68427
# At iterate     1  f =       180.82  |proj g|=       0.53664
# At iterate     2  f =       179.77  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 179.771
#
# F = 179.771
# final  value 179.770758
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.35031 18.27895
#   - best initial criterion value(s) :  -154.6601
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       154.66  |proj g|=       1.9556
# At iterate     1  f =       152.19  |proj g|=       0.65238
# At iterate     2  f =       150.94  |proj g|=       0.82609
# At iterate     3  f =       150.01  |proj g|=       0.11871
# At iterate     4  f =       149.95  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 149.954
#
# F = 149.954
# final  value 149.953968
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  18.35031 18.27895
#   - best initial criterion value(s) :  -179.9049
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        179.9  |proj g|=      0.21957
# At iterate     1  f =       179.77  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 179.771
#
# F = 179.771
# final  value 179.770758
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.53698 19.39211
#   - best initial criterion value(s) :  -190.4079
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       190.41  |proj g|=      0.69383
# At iterate     1  f =       189.97  |proj g|=       0.54424
# At iterate     2  f =       188.74  |proj g|=      0.066588
# At iterate     3  f =       188.73  |proj g|=             0
#
# iterations 3
# function evaluations 4
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 188.725
#
# F = 188.725
# final  value 188.725417
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.53698 19.39211
#   - best initial criterion value(s) :  -164.3907
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       164.39  |proj g|=      0.70971
# At iterate     1  f =       163.56  |proj g|=       0.62234
# At iterate     2  f =       161.37  |proj g|=             0
#
# iterations 2
# function evaluations 3
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 161.369
#
# F = 161.369
# final  value 161.369369
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10
#   - parameters upper bounds :  19.53698 19.39211
#   - best initial criterion value(s) :  -193.0685
#
# N = 2, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       193.07  |proj g|=       1.0136
# At iterate     1  f =       192.22  |proj g|=       0.68251
# At iterate     2  f =       190.43  |proj g|=       0.49762
# At iterate     3  f =       188.75  |proj g|=      0.076836
# At iterate     4  f =       188.73  |proj g|=             0
#
# iterations 4
# function evaluations 5
# segments explored during Cauchy searches 5
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value 188.725
#
# F = 188.725
# final  value 188.725417
# converged

# %%
bla = do.call(rbind, out)

p = ggplot(data = bla, aes(x = misspec, y = neg_loglik, colour = type)) + geom_boxplot() #+ ylim(c(0, 50))
p
# Out:
# plot without title

# %%
bla = setDT(bla)

# %%
out = bla[, .(mean_negloglik = mean(neg_loglik), sd_negloglik = sd(neg_loglik)), by = c("misspec", "type")]

# %%
options(repr.plot.width=10, repr.plot.height=5)

p1 = p + geom_line(data = me_pdp1, aes(x = x1, y = mean, colour = type))
p1 = p1 + geom_ribbon(data = me_pdp1, aes(x = x1, ymin = mean - 2 * sd, ymax = mean + 2 * sd), alpha = 0.2)
p1 = p1 + facet_wrap(. ~ type)
p1
# Out:
# plot without title

# %%
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern3_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.39747 19.92761 19.83641 19.40239 19.15312
#   - best initial criterion value(s) :  -278.5375
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       278.54  |proj g|=           16
# At iterate     1  f =       277.88  |proj g|=       0.21775
# At iterate     2  f =       277.88  |proj g|=       0.17378
# At iterate     3  f =       277.88  |proj g|=       0.17506
# At iterate     4  f =       277.88  |proj g|=       0.38435
# At iterate     5  f =       277.88  |proj g|=       0.83894
# At iterate     6  f =       277.87  |proj g|=        1.5397
# At iterate     7  f =       277.85  |proj g|=        2.5905
# At iterate     8  f =       277.81  |proj g|=        3.8539
# At iterate     9  f =       277.73  |proj g|=        4.4993
# At iterate    10  f =        277.6  |proj g|=        1.2914
# At iterate    11  f =       277.58  |proj g|=       0.05672
# At iterate    12  f =       277.58  |proj g|=        0.1135
# At iterate    13  f =       277.58  |proj g|=       0.27304
# At iterate    14  f =       277.58  |proj g|=       0.20998
# At iterate    15  f =       277.58  |proj g|=       0.09074
# At iterate    16  f =       277.57  |proj g|=       0.15022
# At iterate    17  f =       277.56  |proj g|=       0.20738
# At iterate    18  f =       277.53  |proj g|=       0.21256
# At iterate    19  f =       277.48  |proj g|=       0.22574
# At iterate    20  f =       277.42  |proj g|=       0.48915
# At iterate    21  f =       277.37  |proj g|=       0.22911
# At iterate    22  f =       277.34  |proj g|=       0.23356
# At iterate    23  f =       277.33  |proj g|=       0.24226
# At iterate    24  f =       277.33  |proj g|=      0.020336
# At iterate    25  f =       277.33  |proj g|=      0.020371
# At iterate    26  f =       277.33  |proj g|=       0.10655
# At iterate    27  f =       277.32  |proj g|=       0.20912
# At iterate    28  f =       277.32  |proj g|=      0.044031
# At iterate    29  f =       277.32  |proj g|=     0.0037485
# At iterate    30  f =       277.32  |proj g|=    0.00031645
#
# iterations 30
# function evaluations 37
# segments explored during Cauchy searches 30
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.000316453
# final function value 277.32
#
# F = 277.32
# final  value 277.320453
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  19.39747 19.92761 19.83641 19.40239 19.15312
#   - best initial criterion value(s) :  -279.6439
#
# N = 5, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       279.64  |proj g|=       1.4422
# At iterate     1  f =       279.09  |proj g|=        1.0884
# At iterate     2  f =       278.65  |proj g|=       0.24011
# At iterate     3  f =       278.56  |proj g|=        0.2091
# At iterate     4  f =       278.49  |proj g|=       0.18143
# At iterate     5  f =       278.38  |proj g|=       0.13911
# At iterate     6  f =       278.37  |proj g|=       0.21767
# At iterate     7  f =       278.35  |proj g|=      0.049808
# At iterate     8  f =       278.34  |proj g|=       0.02667
# At iterate     9  f =       278.34  |proj g|=       0.02621
# At iterate    10  f =       278.34  |proj g|=      0.030821
# At iterate    11  f =       278.33  |proj g|=      0.059712
# At iterate    12  f =       278.32  |proj g|=      0.077832
# At iterate    13  f =       278.31  |proj g|=      0.066283
# At iterate    14  f =       278.31  |proj g|=      0.020478
# At iterate    15  f =        278.3  |proj g|=     0.0058399
# At iterate    16  f =        278.3  |proj g|=     0.0046208
# At iterate    17  f =        278.3  |proj g|=     0.0021683
# At iterate    18  f =        278.3  |proj g|=    0.00080122
# At iterate    19  f =        278.3  |proj g|=    0.00049834
#
# iterations 19
# function evaluations 21
# segments explored during Cauchy searches 19
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.000498336
# final function value 278.305
#
# F = 278.305
# final  value 278.304824
# converged
#    x1         mean      sd       type       neg_loglik mean.gt
# 1  -4.9875543 -3.110099 15.47938 pdp_var_gp 3.807779   -11.56960
# 2  -4.4623627 -4.483186 14.90378 pdp_var_gp 3.744703   -11.90968
# 3  -3.9371710 -5.694552 14.37867 pdp_var_gp 3.685955   -12.16560
# 4  -3.4119794 -6.714708 13.91369 pdp_var_gp 3.632234   -12.29486
# 5  -2.8867877 -7.531807 13.51179 pdp_var_gp 3.583964   -12.26913
# 6  -2.3615961 -8.154609 13.16946 pdp_var_gp 3.542329   -12.12688
# 7  -1.8364044 -8.605626 12.87836 pdp_var_gp 3.507823   -11.93097
# 8  -1.3112128 -8.910152 12.62791 pdp_var_gp 3.479854   -11.73420
# 9  -0.7860211 -9.088375 12.40815 pdp_var_gp 3.457257   -11.56785
# 10 -0.2608295 -9.153211 12.21195 pdp_var_gp 3.439172   -11.45855
# 11  0.2643622 -9.105537 12.03725 pdp_var_gp 3.425759   -11.44055
# 12  0.7895538 -8.927879 11.89007 pdp_var_gp 3.418575   -11.52920
# 13  1.3147455 -8.587959 11.78655 pdp_var_gp 3.420862   -11.70480
# 14  1.8399371 -8.049200 11.75090 pdp_var_gp 3.436617   -11.90193
# 15  2.3651288 -7.282925 11.81020 pdp_var_gp 3.469589   -12.05655
# 16  2.8903204 -6.276100 11.98856 pdp_var_gp 3.522307   -12.13497
# 17  3.4155121 -5.034411 12.30140 pdp_var_gp 3.594509   -12.11936
# 18  3.9407038 -3.581093 12.75159 pdp_var_gp 3.682705   -12.00313
# 19  4.4658954 -1.957534 13.32770 pdp_var_gp 3.781125   -11.79374
# 20  4.9910871 -0.222261 14.00506 pdp_var_gp 3.883502   -11.51602
# 21 -4.9875543 -3.110099 62.73192 pdp_var    5.066901   -11.56960
# 22 -4.4623627 -4.483186 61.78459 pdp_var    5.049816   -11.90968
# 23 -3.9371710 -5.694552 60.91758 pdp_var    5.034102   -12.16560
# 24 -3.4119794 -6.714708 60.14381 pdp_var    5.019981   -12.29486
# 25 -2.8867877 -7.531807 59.46565 pdp_var    5.007511   -12.26913
# 26 -2.3615961 -8.154609 58.87697 pdp_var    4.996665   -12.12688
# 27 -1.8364044 -8.605626 58.36744 pdp_var    4.987320   -11.93097
# 28 -1.3112128 -8.910152 57.92759 pdp_var    4.979321   -11.73420
# 29 -0.7860211 -9.088375 57.55304 pdp_var    4.972573   -11.56785
# 30 -0.2608295 -9.153211 57.24640 pdp_var    4.967114   -11.45855
# 31  0.2643622 -9.105537 57.01756 pdp_var    4.963136   -11.44055
# 32  0.7895538 -8.927879 56.88355 pdp_var    4.960990   -11.52920
# 33  1.3147455 -8.587959 56.86757 pdp_var    4.961166   -11.70480
# 34  1.8399371 -8.049200 56.99454 pdp_var    4.964179   -11.90193
# 35  2.3651288 -7.282925 57.28542 pdp_var    4.970457   -12.05655
# 36  2.8903204 -6.276100 57.75355 pdp_var    4.980269   -12.13497
# 37  3.4155121 -5.034411 58.40235 pdp_var    4.993653   -12.11936
# 38  3.9407038 -3.581093 59.22390 pdp_var    5.010375   -12.00313
# 39  4.4658954 -1.957534 60.19789 pdp_var    5.029925   -11.79374
# 40  4.9910871 -0.222261 61.29176 pdp_var    5.051560   -11.51602
